# %% [markdown]
# ## ORM: One-to-Many Relationships with SQLAlchemy

# %%
from sqlalchemy.orm import DeclarativeBase, Mapped, mapped_column, relationship
from sqlalchemy import ForeignKey

"""
table programs
    - id int pk
    - name str
    - years_of_study

table courses
    - id int pk
    - title
    - code
    - program_id => fk => programs.id
"""
# Out:
# '\ntable programs\n    - id int pk\n    - name str\n    - years_of_study\n\ntable courses\n    - id int pk\n    - title\n    - code\n    - program_id => fk => programs.id\n'

# %% [markdown]
# ## Create Model

# %%
class Base(DeclarativeBase):
    pass


class Programs(Base):
    __tablename__ = 'programss'
    id:Mapped[int] = mapped_column(primary_key=True)
    name:Mapped[str] = mapped_column(nullable=False)
    years_of_study:Mapped[int] = mapped_column(nullable=False)
    courses:Mapped[list['Courses']] = relationship(backref='program',passive_deletes=True)

    def __repr__(self) -> str:
        return f"<Program {self.name}>"

# %%
class Courses(Base):
    __tablename__ = 'coursess'
    id:Mapped[int] = mapped_column(primary_key=True)
    title:Mapped[str] = mapped_column(nullable=False)
    code:Mapped[str] = mapped_column(nullable=False)
    program_id:Mapped[int] = mapped_column(ForeignKey('programss.id',ondelete='CASCADE'))

    def __repr__(self) -> str:
        return f"<Course {self.title}>"

# %% [markdown]
# ## Connect and Create Engine and Session

# %%
from sqlalchemy import create_engine, text
from sqlalchemy.orm import sessionmaker
from sqlalchemy.engine.base import Engine
from sqlalchemy.orm.session import Session


engine: Engine = create_engine(
    f'postgresql://k191612:3AueMsX1OSYt@ep-curly-mouse-38234397.us-east-2.aws.neon.tech/test1?sslmode=require',
    echo= True
)


Session = sessionmaker(bind=engine)

db: Session = Session()

# %% [markdown]
# ## Create Database

# %%
Base.metadata.create_all(bind=engine)
# Out:
# 2024-01-19 01:09:23,434 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2024-01-19 01:09:23,437 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-01-19 01:09:24,026 INFO sqlalchemy.engine.Engine select current_schema()
# 2024-01-19 01:09:24,028 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-01-19 01:09:24,635 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2024-01-19 01:09:24,636 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-01-19 01:09:25,227 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-19 01:09:25,241 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2024-01-19 01:09:25,245 INFO sqlalchemy.engine.Engine [generated in 0.00358s] {'table_name': 'programss', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2024-01-19 01:09:25,791 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2024-01-19 01:09:25,794 INFO sqlalchemy.engine.Engine [cached since 0.5533s ago] {'table_name': 'coursess', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2024-01-19 01:09:26,055 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ## Populate Database

# %%
program1 = Programs(
    name = "Bachelors in CS",
    years_of_study =3
)

program2 = Programs(
    name = "Bachelors in Business",
    years_of_study =3
)

# saving programs
db.add_all(
    [program1,program2]
)

db.commit()
# Out:
# 2024-01-19 01:09:28,565 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-19 01:09:28,571 INFO sqlalchemy.engine.Engine INSERT INTO programss (name, years_of_study) SELECT p0::VARCHAR, p1::INTEGER FROM (VALUES (%(name__0)s, %(years_of_study__0)s, 0), (%(name__1)s, %(years_of_study__1)s, 1)) AS imp_sen(p0, p1, sen_counter) ORDER BY sen_counter RETURNING programss.id, programss.id AS id__1
# 2024-01-19 01:09:28,571 INFO sqlalchemy.engine.Engine [generated in 0.00010s (insertmanyvalues) 1/1 (ordered)] {'years_of_study__0': 3, 'name__0': 'Bachelors in CS', 'years_of_study__1': 3, 'name__1': 'Bachelors in Business'}
# 2024-01-19 01:09:29,093 INFO sqlalchemy.engine.Engine COMMIT

# %%
#create course objects
course1 = Courses(
    title ="Database Management Systems",
    code = "CS 102"
)


course2 = Courses(
    title ="Data SCIENCE",
    code = "CS 103"
)


course3 = Courses(
    title ="Data STRUCTURES AND ALGRITHMS",
    code = "CS 110"
)

course4 = Courses(
    title ="Businnes communication",
    code = "BS 123"
)


# adding child object to parent
program1.courses.append(course1)
program1.courses.append(course2)
program1.courses.append(course3)
program2.courses.append(course4)

db.commit()
# Out:
# ---------------------------------------------------------------------------
# PendingRollbackError                      Traceback (most recent call last)
# Cell In[39], line 26
#      19 course4 = Courses(
#      20     title ="Businnes communication",
#      21     code = "BS 123"
#      22 )
#      25 # adding child object to parent
# ---> 26 program1.courses.append(course1)
#      27 program1.courses.append(course2)
#      28 program1.courses.append(course3)
#
# File c:\Users\DELL\anaconda3\envs\python13\Lib\site-packages\sqlalchemy\orm\attributes.py:566, in InstrumentedAttribute.__get__(self, instance, owner)
#     564 except AttributeError as err:
#     565     raise orm_exc.UnmappedInstanceError(instance) from err
# --> 566 return self.impl.get(state, dict_)
#
# File c:\Users\DELL\anaconda3\envs\python13\Lib\site-packages\sqlalchemy\orm\attributes.py:1086, in AttributeImpl.get(self, state, dict_, passive)
#    1083 if not passive & CALLABLES_OK:
#    1084     return PASSIVE_NO_RESULT
# -> 1086 value = self._fire_loader_callables(state, key, passive)
#    1088 if value is PASSIVE_NO_RESULT or value is NO_VALUE:
#    1089     return value
#
# File c:\Users\DELL\anaconda3\envs\python13\Lib\site-packages\sqlalchemy\orm\attributes.py:1121, in AttributeImpl._fire_loader_callables(self, state, key, passive)
#    1119     return callable_(state, passive)
#    1120 elif self.callable_:
# -> 1121     return self.callable_(state, passive)
#    1122 else:
#    1123     return ATTR_EMPTY
#
# File c:\Users\DELL\anaconda3\envs\python13\Lib\site-packages\sqlalchemy\orm\strategies.py:967, in LazyLoader._load_for_state(self, state, passive, loadopt, extra_criteria, extra_options, alternate_effective_path, execution_options)
#     961     elif (
#     962         not passive & PassiveFlag.SQL_OK
#     963         or not passive & PassiveFlag.RELATED_OBJECT_OK
#     964     ):
#     965         return LoaderCallableStatus.PASSIVE_NO_RESULT
# --> 967 return self._emit_lazyload(
#     968     session,
#     969     state,
#     970     primary_key_identity,
#     971     passive,
#     972     loadopt,
#     973     extra_criteria,
#     974     extra_options,
#     975     alternate_effective_path,
#     976     execution_options,
#     977 )
#
# File c:\Users\DELL\anaconda3\envs\python13\Lib\site-packages\sqlalchemy\orm\strategies.py:1098, in LazyLoader._emit_lazyload(self, session, state, primary_key_identity, passive, loadopt, extra_criteria, extra_options, alternate_effective_path, execution_options)
#    1088             strategy_options.Load._construct_for_existing_path(
#    1089                 compile_context.compile_options._current_path[
#    1090                     rev.parent
#    1091                 ]
#    1092             ).lazyload(rev).process_compile_state(compile_context)
#    1094 stmt._with_context_options += (
#    1095     (_lazyload_reverse, self.parent_property),
#    1096 )
# -> 1098 lazy_clause, params = self._generate_lazy_clause(state, passive)
#    1100 if execution_options:
#    1101     execution_options = util.EMPTY_DICT.merge_with(
#    1102         execution_options,
#    1103         {
#    1104             "_sa_orm_load_options": load_options,
#    1105         },
#    1106     )
#
# File c:\Users\DELL\anaconda3\envs\python13\Lib\site-packages\sqlalchemy\orm\strategies.py:854, in LazyLoader._generate_lazy_clause(self, state, passive)
#     850             value = mapper._get_committed_state_attr_by_column(
#     851                 state, dict_, ident, passive
#     852             )
#     853         else:
# --> 854             value = mapper._get_state_attr_by_column(
#     855                 state, dict_, ident, passive
#     856             )
#     858     params[key] = value
#     860 return criterion, params
#
# File c:\Users\DELL\anaconda3\envs\python13\Lib\site-packages\sqlalchemy\orm\mapper.py:3577, in Mapper._get_state_attr_by_column(self, state, dict_, column, passive)
#    3569 def _get_state_attr_by_column(
#    3570     self,
#    3571     state: InstanceState[_O],
#    (...)
#    3574     passive: PassiveFlag = PassiveFlag.PASSIVE_RETURN_NO_VALUE,
#    3575 ) -> Any:
#    3576     prop = self._columntoproperty[column]
# -> 3577     return state.manager[prop.key].impl.get(state, dict_, passive=passive)
#
# File c:\Users\DELL\anaconda3\envs\python13\Lib\site-packages\sqlalchemy\orm\attributes.py:1086, in AttributeImpl.get(self, state, dict_, passive)
#    1083 if not passive & CALLABLES_OK:
#    1084     return PASSIVE_NO_RESULT
# -> 1086 value = self._fire_loader_callables(state, key, passive)
#    1088 if value is PASSIVE_NO_RESULT or value is NO_VALUE:
#    1089     return value
#
# File c:\Users\DELL\anaconda3\envs\python13\Lib\site-packages\sqlalchemy\orm\attributes.py:1116, in AttributeImpl._fire_loader_callables(self, state, key, passive)
#    1108 def _fire_loader_callables(
#    1109     self, state: InstanceState[Any], key: str, passive: PassiveFlag
#    1110 ) -> Any:
#    1111     if (
#    1112         self.accepts_scalar_loader
#    1113         and self.load_on_unexpire
#    1114         and key in state.expired_attributes
#    1115     ):
# -> 1116         return state._load_expired(state, passive)
#    1117     elif key in state.callables:
#    1118         callable_ = state.callables[key]
#
# File c:\Users\DELL\anaconda3\envs\python13\Lib\site-packages\sqlalchemy\orm\state.py:798, in InstanceState._load_expired(self, state, passive)
#     791 toload = self.expired_attributes.intersection(self.unmodified)
#     792 toload = toload.difference(
#     793     attr
#     794     for attr in toload
#     795     if not self.manager[attr].impl.load_on_unexpire
#     796 )
# --> 798 self.manager.expired_attribute_loader(self, toload, passive)
#     800 # if the loader failed, or this
#     801 # instance state didn't have an identity,
#     802 # the attributes still might be in the callables
#     803 # dict.  ensure they are removed.
#     804 self.expired_attributes.clear()
#
# File c:\Users\DELL\anaconda3\envs\python13\Lib\site-packages\sqlalchemy\orm\loading.py:1651, in load_scalar_attributes(mapper, state, attribute_names, passive)
#    1643     util.warn_limited(
#    1644         "Instance %s to be refreshed doesn't "
#    1645         "contain a full primary key - can't be refreshed "
#    1646         "(and shouldn't be expired, either).",
#    1647         state_str(state),
#    1648     )
#    1649     return
# -> 1651 result = load_on_ident(
#    1652     session,
#    1653     select(mapper).set_label_style(LABEL_STYLE_TABLENAME_PLUS_COL),
#    1654     identity_key,
#    1655     refresh_state=state,
#    1656     only_load_props=attribute_names,
#    1657     no_autoflush=no_autoflush,
#    1658 )
#    1660 # if instance is pending, a refresh operation
#    1661 # may not complete (even if PK attributes are assigned)
#    1662 if has_key and result is None:
#
# File c:\Users\DELL\anaconda3\envs\python13\Lib\site-packages\sqlalchemy\orm\loading.py:507, in load_on_ident(session, statement, key, load_options, refresh_state, with_for_update, only_load_props, no_autoflush, bind_arguments, execution_options, require_pk_cols, is_user_refresh)
#     504 else:
#     505     ident = identity_token = None
# --> 507 return load_on_pk_identity(
#     508     session,
#     509     statement,
#     510     ident,
#     511     load_options=load_options,
#     512     refresh_state=refresh_state,
#     513     with_for_update=with_for_update,
#     514     only_load_props=only_load_props,
#     515     identity_token=identity_token,
#     516     no_autoflush=no_autoflush,
#     517     bind_arguments=bind_arguments,
#     518     execution_options=execution_options,
#     519     require_pk_cols=require_pk_cols,
#     520     is_user_refresh=is_user_refresh,
#     521 )
#
# File c:\Users\DELL\anaconda3\envs\python13\Lib\site-packages\sqlalchemy\orm\loading.py:692, in load_on_pk_identity(session, statement, primary_key_identity, load_options, refresh_state, with_for_update, only_load_props, identity_token, no_autoflush, bind_arguments, execution_options, require_pk_cols, is_user_refresh)
#     686     load_options += {"_autoflush": False}
#     688 execution_options = util.EMPTY_DICT.merge_with(
#     689     execution_options, {"_sa_orm_load_options": load_options}
#     690 )
#     691 result = (
# --> 692     session.execute(
#     693         q,
#     694         params=params,
#     695         execution_options=execution_options,
#     696         bind_arguments=bind_arguments,
#     697     )
#     698     .unique()
#     699     .scalars()
#     700 )
#     702 try:
#     703     return result.one()
#
# File c:\Users\DELL\anaconda3\envs\python13\Lib\site-packages\sqlalchemy\orm\session.py:2308, in Session.execute(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event)
#    2247 def execute(
#    2248     self,
#    2249     statement: Executable,
#    (...)
#    2255     _add_event: Optional[Any] = None,
#    2256 ) -> Result[Any]:
#    2257     r"""Execute a SQL expression construct.
#    2258
#    2259     Returns a :class:`_engine.Result` object representing
#    (...)
#    2306
#    2307     """
# -> 2308     return self._execute_internal(
#    2309         statement,
#    2310         params,
#    2311         execution_options=execution_options,
#    2312         bind_arguments=bind_arguments,
#    2313         _parent_execute_state=_parent_execute_state,
#    2314         _add_event=_add_event,
#    2315     )
#
# File c:\Users\DELL\anaconda3\envs\python13\Lib\site-packages\sqlalchemy\orm\session.py:2180, in Session._execute_internal(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event, _scalar_result)
#    2166     (
#    2167         statement,
#    2168         execution_options,
#    (...)
#    2175         False,
#    2176     )
#    2178 bind = self.get_bind(**bind_arguments)
# -> 2180 conn = self._connection_for_bind(bind)
#    2182 if _scalar_result and not compile_state_cls:
#    2183     if TYPE_CHECKING:
#
# File c:\Users\DELL\anaconda3\envs\python13\Lib\site-packages\sqlalchemy\orm\session.py:2047, in Session._connection_for_bind(self, engine, execution_options, **kw)
#    2045 if trans is None:
#    2046     trans = self._autobegin_t()
# -> 2047 return trans._connection_for_bind(engine, execution_options)
#
# File <string>:2, in _connection_for_bind(self, bind, execution_options)
#
# File c:\Users\DELL\anaconda3\envs\python13\Lib\site-packages\sqlalchemy\orm\state_changes.py:103, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#      97 current_state = self._state
#      99 if (
#     100     has_prerequisite_states
#     101     and current_state not in prerequisite_state_collection
#     102 ):
# --> 103     self._raise_for_prerequisite_state(fn.__name__, current_state)
#     105 next_state = self._next_state
#     106 existing_fn = self._current_fn
#
# File c:\Users\DELL\anaconda3\envs\python13\Lib\site-packages\sqlalchemy\orm\session.py:929, in SessionTransaction._raise_for_prerequisite_state(self, operation_name, state)
#     927 if state is SessionTransactionState.DEACTIVE:
#     928     if self._rollback_exception:
# --> 929         raise sa_exc.PendingRollbackError(
#     930             "This Session's transaction has been rolled back "
#     931             "due to a previous exception during flush."
#     932             " To begin a new transaction with this Session, "
#     933             "first issue Session.rollback()."
#     934             f" Original exception was: {self._rollback_exception}",
#     935             code="7s2a",
#     936         )
#     937     else:
#     938         raise sa_exc.InvalidRequestError(
#     939             "This session is in 'inactive' state, due to the "
#     940             "SQL transaction being rolled back; no further SQL "
#     941             "can be emitted within this transaction."
#     942         )
#
# PendingRollbackError: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (raised as a result of Query-invoked autoflush; consider using a session.no_autoflush block if this flush is occurring prematurely)
# (psycopg2.errors.ForeignKeyViolation) insert or update on table "coursess" violates foreign key constraint "coursess_program_id_fkey"
# DETAIL:  Key (program_id)=(1) is not present in table "programs".
#
# [SQL: INSERT INTO coursess (title, code, program_id) SELECT p0::VARCHAR, p1::VARCHAR, p2::INTEGER FROM (VALUES (%(title__0)s, %(code__0)s, %(program_id__0)s, 0), (%(title__1)s, %(code__1)s, %(program_id__1)s, 1), (%(title__2)s, %(code__2)s, %(program_id__2)s, 2)) AS imp_sen(p0, p1, p2, sen_counter) ORDER BY sen_counter RETURNING coursess.id, coursess.id AS id__1]
# [parameters: {'program_id__0': 1, 'code__0': 'CS 102', 'title__0': 'Database Management Systems', 'program_id__1': 1, 'code__1': 'CS 103', 'title__1': 'Data SCIENCE', 'program_id__2': 1, 'code__2': 'CS 110', 'title__2': 'Data STRUCTURES AND ALGRITHMS'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj) (Background on this error at: https://sqlalche.me/e/20/7s2a)

# %% [markdown]
# ## Query Database

# %%
myprogram1: Programs = db.query(Programs).filter_by(name = "Bachelors in CS").first()
print(myprogram1.name)

mycourse3: Courses = db.query(Courses).filter_by(title='Data STRUCTURES AND ALGRITHMS').first()
print(mycourse3.title)
# Out:
# ---------------------------------------------------------------------------
# PendingRollbackError                      Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 myprogram1: Programs = db.query(Programs).filter_by(name = "Bachelors in CS").first()
#       2 print(myprogram1.name)
#       4 mycourse3: Courses = db.query(Courses).filter_by(title='Data STRUCTURES AND ALGRITHMS').first()
#
# File c:\Users\DELL\anaconda3\envs\python13\Lib\site-packages\sqlalchemy\orm\query.py:2748, in Query.first(self)
#    2746     return self._iter().first()  # type: ignore
#    2747 else:
# -> 2748     return self.limit(1)._iter().first()
#
# File c:\Users\DELL\anaconda3\envs\python13\Lib\site-packages\sqlalchemy\orm\query.py:2847, in Query._iter(self)
#    2844 params = self._params
#    2846 statement = self._statement_20()
# -> 2847 result: Union[ScalarResult[_T], Result[_T]] = self.session.execute(
#    2848     statement,
#    2849     params,
#    2850     execution_options={"_sa_orm_load_options": self.load_options},
#    2851 )
#    2853 # legacy: automatically set scalars, unique
#    2854 if result._attributes.get("is_single_entity", False):
#
# File c:\Users\DELL\anaconda3\envs\python13\Lib\site-packages\sqlalchemy\orm\session.py:2308, in Session.execute(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event)
#    2247 def execute(
#    2248     self,
#    2249     statement: Executable,
#    (...)
#    2255     _add_event: Optional[Any] = None,
#    2256 ) -> Result[Any]:
#    2257     r"""Execute a SQL expression construct.
#    2258
#    2259     Returns a :class:`_engine.Result` object representing
#    (...)
#    2306
#    2307     """
# -> 2308     return self._execute_internal(
#    2309         statement,
#    2310         params,
#    2311         execution_options=execution_options,
#    2312         bind_arguments=bind_arguments,
#    2313         _parent_execute_state=_parent_execute_state,
#    2314         _add_event=_add_event,
#    2315     )
#
# File c:\Users\DELL\anaconda3\envs\python13\Lib\site-packages\sqlalchemy\orm\session.py:2180, in Session._execute_internal(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event, _scalar_result)
#    2166     (
#    2167         statement,
#    2168         execution_options,
#    (...)
#    2175         False,
#    2176     )
#    2178 bind = self.get_bind(**bind_arguments)
# -> 2180 conn = self._connection_for_bind(bind)
#    2182 if _scalar_result and not compile_state_cls:
#    2183     if TYPE_CHECKING:
#
# File c:\Users\DELL\anaconda3\envs\python13\Lib\site-packages\sqlalchemy\orm\session.py:2047, in Session._connection_for_bind(self, engine, execution_options, **kw)
#    2045 if trans is None:
#    2046     trans = self._autobegin_t()
# -> 2047 return trans._connection_for_bind(engine, execution_options)
#
# File <string>:2, in _connection_for_bind(self, bind, execution_options)
#
# File c:\Users\DELL\anaconda3\envs\python13\Lib\site-packages\sqlalchemy\orm\state_changes.py:103, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#      97 current_state = self._state
#      99 if (
#     100     has_prerequisite_states
#     101     and current_state not in prerequisite_state_collection
#     102 ):
# --> 103     self._raise_for_prerequisite_state(fn.__name__, current_state)
#     105 next_state = self._next_state
#     106 existing_fn = self._current_fn
#
# File c:\Users\DELL\anaconda3\envs\python13\Lib\site-packages\sqlalchemy\orm\session.py:929, in SessionTransaction._raise_for_prerequisite_state(self, operation_name, state)
#     927 if state is SessionTransactionState.DEACTIVE:
#     928     if self._rollback_exception:
# --> 929         raise sa_exc.PendingRollbackError(
#     930             "This Session's transaction has been rolled back "
#     931             "due to a previous exception during flush."
#     932             " To begin a new transaction with this Session, "
#     933             "first issue Session.rollback()."
#     934             f" Original exception was: {self._rollback_exception}",
#     935             code="7s2a",
#     936         )
#     937     else:
#     938         raise sa_exc.InvalidRequestError(
#     939             "This session is in 'inactive' state, due to the "
#     940             "SQL transaction being rolled back; no further SQL "
#     941             "can be emitted within this transaction."
#     942         )
#
# PendingRollbackError: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (raised as a result of Query-invoked autoflush; consider using a session.no_autoflush block if this flush is occurring prematurely)
# (psycopg2.errors.ForeignKeyViolation) insert or update on table "coursess" violates foreign key constraint "coursess_program_id_fkey"
# DETAIL:  Key (program_id)=(1) is not present in table "programs".
#
# [SQL: INSERT INTO coursess (title, code, program_id) SELECT p0::VARCHAR, p1::VARCHAR, p2::INTEGER FROM (VALUES (%(title__0)s, %(code__0)s, %(program_id__0)s, 0), (%(title__1)s, %(code__1)s, %(program_id__1)s, 1), (%(title__2)s, %(code__2)s, %(program_id__2)s, 2)) AS imp_sen(p0, p1, p2, sen_counter) ORDER BY sen_counter RETURNING coursess.id, coursess.id AS id__1]
# [parameters: {'program_id__0': 1, 'code__0': 'CS 102', 'title__0': 'Database Management Systems', 'program_id__1': 1, 'code__1': 'CS 103', 'title__1': 'Data SCIENCE', 'program_id__2': 1, 'code__2': 'CS 110', 'title__2': 'Data STRUCTURES AND ALGRITHMS'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj) (Background on this error at: https://sqlalche.me/e/20/7s2a)

# %% [markdown]
# ## Delete Rows

# %%
db.delete(myprogram1)

db.commit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 db.delete(myprogram1)
#       3 db.commit()
#
# NameError: name 'myprogram1' is not defined
