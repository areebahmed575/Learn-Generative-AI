# %%
# %%capture --no-stderr
# !pip install composio-langgraph==0.7.15 composio langgraph langchain_openai composio_langchain==0.8.0 langchain

# %%
import os
from google.colab import userdata

os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')
os.environ["COMPOSIO_API_KEY"] = userdata.get('COMPOSIO_API_KEY')

# %%
from typing import Literal
from langchain_openai import ChatOpenAI
from langgraph.graph import MessagesState, StateGraph
from langgraph.prebuilt import ToolNode
# from composio import Composio
# from composio.types import Tool

# composio = Composio()
# user_id = "pg-test-f211b19e-0250-449c-a"  # Use your email or a unique identifier

# %%
from composio import Composio
from composio_langchain import LangchainProvider
from langchain_openai import ChatOpenAI
from langchain.agents import AgentExecutor, create_openai_functions_agent

# Initialize Composio with the LangChain provider
composio = Composio(provider=LangchainProvider())

# Get the tools (replace user_id etc as appropriate)
tools = composio.tools.get(
    user_id="your_user_id",
    toolkits=[
        "GOOGLECALENDAR_FIND_FREE_SLOTS",
        "GOOGLECALENDAR_CREATE_EVENT",
        "GMAIL_CREATE_EMAIL_DRAFT"
    ]
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-890363041.py in <cell line: 0>()
#       2 from composio_langchain import LangchainProvider
#       3 from langchain_openai import ChatOpenAI
# ----> 4 from langchain.agents import AgentExecutor, create_openai_functions_agent
#       5
#       6 # Initialize Composio with the LangChain provider
#
# ImportError: cannot import name 'AgentExecutor' from 'langchain.agents' (/usr/local/lib/python3.12/dist-packages/langchain/agents/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
tool_node = ToolNode(tools)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3852116963.py in <cell line: 0>()
# ----> 1 tool_node = ToolNode(tools)
#
# /usr/local/lib/python3.12/dist-packages/langgraph/prebuilt/tool_node.py in __init__(self, tools, name, tags, handle_tool_errors, messages_key, wrap_tool_call, awrap_tool_call)
#     675         for tool in tools:
#     676             if not isinstance(tool, BaseTool):
# --> 677                 tool_ = create_tool(cast("type[BaseTool]", tool))
#     678             else:
#     679                 tool_ = tool
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/tools/convert.py in tool(name_or_callable, runnable, description, return_direct, args_schema, infer_schema, response_format, parse_docstring, error_on_invalid_docstring, *args)
#     354             f"for tool decorator. Got {type(name_or_callable)}"
#     355         )
# --> 356         raise ValueError(msg)
#     357
#     358     # Tool is used as a decorator with parameters specified
#
# ValueError: The first argument must be a string or a callable with a __name__ for tool decorator. Got <class 'dict'>
