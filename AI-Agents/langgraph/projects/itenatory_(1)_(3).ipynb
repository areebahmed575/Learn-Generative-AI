# %%
# %%capture --no-stderr
# %pip install --quiet -U langchain_core langgraph langchain_google_genai serpapi tavily-python langchain_community langchain_groq langchain_openai

# %%
from google.colab import userdata
google_api_key = userdata.get('GEMINI_API_KEY')

# %%
from google.colab import userdata
groq_api_key = userdata.get('GROQ_API_KET')
SERPAPI_API_KEY = userdata.get('SERPAPI_API_KEY')
open_api_key = userdata.get('OPENAI_API_KEY')

# %%
import os
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"] = "langchain-academy"
os.environ["TAVILY_API_KEY"] = userdata.get("TAVILY_API_KEY")

# %%
# from langchain_groq import ChatGroq
# llm = ChatGroq(
#     model="gemma2-9b-it",
#     max_retries=2,
#     api_key=groq_api_key
# )

# llm.invoke("greet me")
# Out:
# /usr/local/lib/python3.11/dist-packages/langsmith/client.py:253: LangSmithMissingAPIKeyWarning: API key must be provided when using hosted LangSmith API
#   warnings.warn(
# AIMessage(content='Hello! 👋  How can I help you today? 😊\n', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 11, 'total_tokens': 26, 'completion_time': 0.027272727, 'prompt_time': 7.596e-05, 'queue_time': 0.023044297000000002, 'total_time': 0.027348687}, 'model_name': 'gemma2-9b-it', 'system_fingerprint': 'fp_10c08bf97d', 'finish_reason': 'stop', 'logprobs': None}, id='run-3e09c77e-f830-4554-ba0e-202863efb04f-0', usage_metadata={'input_tokens': 11, 'output_tokens': 15, 'total_tokens': 26})
# WARNING:langsmith.client:Failed to multipart ingest runs: langsmith.utils.LangSmithAuthError: Authentication failed for https://api.smith.langchain.com/runs/multipart. HTTPError('401 Client Error: Unauthorized for url: https://api.smith.langchain.com/runs/multipart', '{"detail":"Invalid token"}')trace=3e09c77e-f830-4554-ba0e-202863efb04f,id=3e09c77e-f830-4554-ba0e-202863efb04f

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4o-mini", api_key=open_api_key)
llm.invoke("greet me")
# Out:
# WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithAuthError: Authentication failed for https://api.smith.langchain.com/runs/multipart. HTTPError('401 Client Error: Unauthorized for url: https://api.smith.langchain.com/runs/multipart', '{"detail":"Invalid token"}')
# AIMessage(content='Hello! How are you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 10, 'total_tokens': 18, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_72ed7ab54c', 'finish_reason': 'stop', 'logprobs': None}, id='run-a3873de3-c5d1-498f-befb-a61566212e81-0', usage_metadata={'input_tokens': 10, 'output_tokens': 8, 'total_tokens': 18, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
# WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithAuthError: Authentication failed for https://api.smith.langchain.com/runs/multipart. HTTPError('401 Client Error: Unauthorized for url: https://api.smith.langchain.com/runs/multipart', '{"detail":"Invalid token"}')

# %%
# from langchain_core.messages import AIMessage, HumanMessage, SystemMessage,ToolMessage
# from langchain_google_genai import ChatGoogleGenerativeAI
# llm: ChatGoogleGenerativeAI = ChatGoogleGenerativeAI(model="gemini-1.5-flash", api_key=google_api_key)
# messages = [HumanMessage(content="What is your name?")]
# result = llm.invoke(messages)
# print(result)
# Out:
# content="I don't have a name. I am a large language model, trained by Google." additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []} id='run-8404c701-7bf2-4d8e-9595-20632a226146-0' usage_metadata={'input_tokens': 6, 'output_tokens': 20, 'total_tokens': 26, 'input_token_details': {'cache_read': 0}}

# %%
# from langgraph.graph import MessagesState
# from typing import TypedDict, List, Annotated, Union
# from langchain_core.messages import AIMessage, HumanMessage, SystemMessage,ToolMessage
# import operator
# class AgentState(TypedDict):
#     messages: Annotated[List[Union[HumanMessage, AIMessage, SystemMessage]], operator.add]
#     # budget: float
#     # interests: List[str]
#     # companions: int
#     # city: str
#     # days: int
#     # travel_date: str
#     # itinerary: List[dict]  # To store the final itinerary

# %%
from langgraph.graph import MessagesState
from typing import TypedDict, List, Annotated, Union
class AgentState(MessagesState):
    # pass
    # messages: Annotated[List[Union[HumanMessage, AIMessage, SystemMessage]], operator.add]
    budget: float
    interests: List[str]
    companions: int
    city: str
    days: int
    travel_date: str
    itinerary: List[dict]  # To store the final itinerary

# %%
def get_system_prompt(state: AgentState):
    return f"""You are a smart travel assistant. Create a detailed itinerary in JSON format considering:
    - Budget: ${state['budget']}
    - Travel Interests: {', '.join(state['interests'])}
    - Companions: {state['companions']} people
    - Destination: {state['city']}
    - Duration: {state['days']} days
    - Travel Date: {state['travel_date']}

    Use the hotels_finder tool to get hotel information and the image_finder tool to get high-quality images for activities and locations.
    For each activity or location, use the image_finder tool to search for relevant images. Choose the best image that represents the location or activity.

    The response should be a valid JSON object with the following structure:
    {{
        "trip_details": {{
            "destination": string,
            "duration": number,
            "travel_date": string,
            "companions": number,
            "budget": number,
            "interests": string[]
        }},
        "daily_itinerary": [
            {{
                "day": number,
                "date": string,
                "day_title": string,  # e.g., "Cultural Tour", "Arrival Day", "Adventure Day"
                "description": string,  # Brief description of the day's theme and activities
                "hotel": {{
                    "name": string,
                    "price": number,
                    "rating": number,
                    "reviews": number,
                    "image_url": string,
                    "booking_url": string
                }},
                "transportation": {{
                    "type": string,
                    "cost": number
                }},
                "meals": [
                    {{
                        "type": string,
                        "venue": string,
                        "cost": number,
                        "image_url": string
                    }}
                ],
                "activities": [
                    {{
                        "name": string,
                        "description": string,
                        "cost": number,
                        "image_url": string,
                        "location_images": [
                            {{
                                "url": string,
                                "title": string,
                                "source": string
                            }}
                        ]
                    }}
                ],
                "daily_cost_breakdown": {{
                    "hotel": number,
                    "transportation": number,
                    "food": number,
                    "activities": number,
                    "total": number
                }}
            }}
        ],
        "cost_summary": {{
            "daily_totals": [
                {{
                    "day": number,
                    "amount": number
                }}
            ],
            "total_cost": number,
            "remaining_budget": number
        }}
    }}

    For each activity:
    1. Use image_finder to get relevant images of the location/activity
    2. Include multiple images in the location_images array
    3. Ensure all image URLs are valid and accessible

    For each day:
    1. Provide a meaningful day_title that describes the theme (e.g., "Cultural Tour", "Adventure Day")
    2. Include a brief description explaining the day's focus and highlights
    3. Break down costs into categories (hotel, transportation, food, activities)
    4. Calculate and include the daily total

    In the cost_summary:
    1. List the total cost for each day
    2. Calculate the total trip cost
    3. Show the remaining budget from the original amount
    """

# %%
from langchain_core.tools import tool

from typing import Optional

from pydantic import BaseModel, Field
import serpapi
# from langchain.pydantic_v1 import BaseModel, Field
from langchain_core.tools import tool

class HotelsInput(BaseModel):
    q: str = Field(description='Location of the hotel')
    check_in_date: str = Field(description='Check-in date. The format is YYYY-MM-DD. e.g. 2024-06-22')
    check_out_date: str = Field(description='Check-out date. The format is YYYY-MM-DD. e.g. 2024-06-28')
    sort_by: Optional[str] = Field(8, description='Parameter is used for sorting the results. Default is sort by highest rating')
    adults: Optional[int] = Field(1, description='Number of adults. Default to 1.')
    children: Optional[int] = Field(0, description='Number of children. Default to 0.')
    rooms: Optional[int] = Field(1, description='Number of rooms. Default to 1.')
    hotel_class: Optional[str] = Field(
        None, description='Parameter defines to include only certain hotel class in the results. for example- 2,3,4')


class HotelsInputSchema(BaseModel):
    params: HotelsInput


@tool(args_schema=HotelsInputSchema)
def hotels_finder(params: HotelsInput):
    '''
    Find hotels using the Google Hotels engine.

    Returns:
        dict: Hotel search results.
    '''
    print(f"calling...")



    params = {
        'api_key': SERPAPI_API_KEY,
        'engine': 'google_hotels',
        'hl': 'en',
        'gl': 'pk',
        'q': params.q,
        'check_in_date': params.check_in_date,
        'check_out_date': params.check_out_date,
        'currency': 'PKR',
        'adults': params.adults,
        'children': params.children,
        'rooms': params.rooms,
        'sort_by': params.sort_by,
        'hotel_class': params.hotel_class
    }
    print(f"calling again...")

    search = serpapi.search(params)
    results = search.data
    print(f"hotels results",results)
    return results['properties'][:5]

# %%
# params = {
#   "engine": "google_images",
#   "q": "Coffee",
#   "location": "Austin, TX, Texas, United States",
#   "api_key": "b3b9af9980f5c2d3e0b0a93e320ea0062f861b5914603bfb322f2ad88c9b2b3e"
# }

# search = serpapi.search(params)
# results = search.data
# print(results)
# Out:
# {'search_metadata': {'id': '679e3eb46b0b01bbe0b3af96', 'status': 'Success', 'json_endpoint': 'https://serpapi.com/searches/c5d60cf7aad77fc2/679e3eb46b0b01bbe0b3af96.json', 'created_at': '2025-02-01 15:33:08 UTC', 'processed_at': '2025-02-01 15:33:08 UTC', 'google_images_url': 'https://www.google.com/search?q=Coffee&oq=Coffee&uule=w+CAIQICIdQXVzdGluLFRYLFRleGFzLFVuaXRlZCBTdGF0ZXM&hl=en&gl=us&tbm=isch', 'raw_html_file': 'https://serpapi.com/searches/c5d60cf7aad77fc2/679e3eb46b0b01bbe0b3af96.html', 'total_time_taken': 3.13}, 'search_parameters': {'engine': 'google_images', 'q': 'Coffee', 'location_requested': 'Austin, TX, Texas, United States', 'location_used': 'Austin,TX,Texas,United States', 'google_domain': 'google.com', 'hl': 'en', 'gl': 'us', 'device': 'desktop'}, 'search_information': {'image_results_state': 'Results for exact spelling'}, 'suggested_searches': [{'name': 'Cup', 'link': 'https://www.google.com/search?sca_esv=f56a266850138bc2&gl=us&hl=en&q=coffee+cup&uds=ABqPDvztZD_Nu18FR6tNPw2cK_RRlbyHxIEdJnJjoCLMRKFTAnpUjFD6kn1ymoDzHKsO80vcFhXgksMfFVBBeRR2MuE2Cix3YIsFY9MejD3kbZ4L8qkJ7KpFsIoW3KCalUDlNyC0HCfH8bdd-ei5iC6q8-MkIEDG7A&udm=2&sa=X&ved=2ahUKEwifoqKD5qKLAxUqLrkGHSNcNvMQxKsJegQIDBAB&ictx=0', 'uds': 'ABqPDvztZD_Nu18FR6tNPw2cK_RRlbyHxIEdJnJjoCLMRKFTAnpUjFD6kn1ymoDzHKsO80vcFhXgksMfFVBBeRR2MuE2Cix3YIsFY9MejD3kbZ4L8qkJ7KpFsIoW3KCalUDlNyC0HCfH8bdd-ei5iC6q8-MkIEDG7A', 'q': 'coffee cup', 'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google_images&gl=us&google_domain=google.com&hl=en&location=Austin%2C+TX%2C+Texas%2C+United+States&q=coffee+cup&uds=ABqPDvztZD_Nu18FR6tNPw2cK_RRlbyHxIEdJnJjoCLMRKFTAnpUjFD6kn1ymoDzHKsO80vcFhXgksMfFVBBeRR2MuE2Cix3YIsFY9MejD3kbZ4L8qkJ7KpFsIoW3KCalUDlNyC0HCfH8bdd-ei5iC6q8-MkIEDG7A', 'thumbnail': 'https://serpapi.com/searches/679e3eb46b0b01bbe0b3af96/images/b04666a7679113802fed9fe32a5ccbabe52e0c0ec2224a2c4af14a9679412ace.jpeg'}, {'name': 'Cafe', 'link': 'https://www.google.com/search?sca_esv=f56a266850138bc2&gl=us&hl=en&q=cafe+coffee&uds=ABqPDvztZD_Nu18FR6tNPw2cK_RRgPocZNJgYutdBYynNDH3jj10ASfPjVZGHjIp_5Mem90I96EAw2l52AFQWUMU4QjjyrBuo6amcJAfQs6L359oQi6DOuG-GKxm-l1flRJLPfSH9utnDmKUREpUQ8hqhnOkk2oeXQ&udm=2&sa=X&ved=2ahUKEwifoqKD5qKLAxUqLrkGHSNcNvMQxKsJegQIDRAB&ictx=0', 'uds': 'ABqPDvztZD_Nu18FR6tNPw2cK_RRgPocZNJgYutdBYynNDH3jj10ASfPjVZGHjIp_5Mem90I96EAw2l52AFQWUMU4QjjyrBuo6amcJAfQs6L359oQi6DOuG-GKxm-l1flRJLPfSH9utnDmKUREpUQ8hqhnOkk2oeXQ', 'q': 'cafe coffee', 'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google_images&gl=us&google_domain=google.com&hl=en&location=Austin%2C+TX%2C+Texas%2C+United+States&q=cafe+coffee&uds=ABqPDvztZD_Nu18FR6tNPw2cK_RRgPocZNJgYutdBYynNDH3jj10ASfPjVZGHjIp_5Mem90I96EAw2l52AFQWUMU4QjjyrBuo6amcJAfQs6L359oQi6DOuG-GKxm-l1flRJLPfSH9utnDmKUREpUQ8hqhnOkk2oeXQ', 'thumbnail': 'https://serpapi.com/searches/679e3eb46b0b01bbe0b3af96/images/b04666a7679113802fed9fe32a5ccbab4049497ffcc14c7dcb6dd15c294824af.jpeg'}, {'name': 'Wallpaper', 'link': 'https://www.google.com/search?sca_esv=f56a266850138bc2&gl=us&hl=en&q=coffee+wallpaper&uds=ABqPDvztZD_Nu18FR6tNPw2cK_RRERO65r54e_IGm506TWGb5slkQCXNH4RnGfuXVSnYo0_IJFJAo8LQbehspFTAjMrrvpzNwWGp2148DhpLvI2wxwt3SbYZCMRh69j-S1pNyJF1eSzTkYkz4un3jnIeI-GIJcDGDA&udm=2&sa=X&ved=2ahUKEwifoqKD5qKLAxUqLrkGHSNcNvMQxKsJegQICxAB&ictx=0', 'uds': 'ABqPDvztZD_Nu18FR6tNPw2cK_RRERO65r54e_IGm506TWGb5slkQCXNH4RnGfuXVSnYo0_IJFJAo8LQbehspFTAjMrrvpzNwWGp2148DhpLvI2wxwt3SbYZCMRh69j-S1pNyJF1eSzTkYkz4un3jnIeI-GIJcDGDA', 'q': 'coffee wallpaper', 'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google_images&gl=us&google_domain=google.com&hl=en&location=Austin%2C+TX%2C+Texas%2C+United+States&q=coffee+wallpaper&uds=ABqPDvztZD_Nu18FR6tNPw2cK_RRERO65r54e_IGm506TWGb5slkQCXNH4RnGfuXVSnYo0_IJFJAo8LQbehspFTAjMrrvpzNwWGp2148DhpLvI2wxwt3SbYZCMRh69j-S1pNyJF1eSzTkYkz4un3jnIeI-GIJcDGDA', 'thumbnail': 'https://serpapi.com/searches/679e3eb46b0b01bbe0b3af96/images/b04666a7679113802fed9fe32a5ccbaba9d8160f312e222fb899dc5884237d09.j ...

# %%
from pydantic import BaseModel, Field
from typing import Optional, List





# Define Pydantic Models
class ImageSearchInput(BaseModel):
    q: str = Field(description="Search query for the image")
    safe: Optional[str] = Field("active", description="Safe search setting: active, moderate, or off")


class ImageSearchInputSchema(BaseModel):
    params: ImageSearchInput


# Define Image Search Function
def image_finder(params: ImageSearchInput) -> List[dict]:
    """
    Find images using Google Images via SerpAPI.
    Returns a list of image results with URLs and metadata.
    """
    search_params = {
        "api_key": SERPAPI_API_KEY,
        "engine": "google_images",
        "q": params.q,
        "safe": params.safe,
        "hl": "en",
        "gl": "pk",
    }

    search = serpapi.search(search_params)
    results = search.data

    if "images_results" in results:
        images = results["images_results"][:10]
        processed_results = [
            {
                "original": img.get("original", ""),
                "thumbnail": img.get("thumbnail", ""),
                "title": img.get("title", ""),
                "source": img.get("source", ""),
                "width": img.get("original_width", 0),
                "height": img.get("original_height", 0),
            }
            for img in images
        ]
        return processed_results

    return []  # Return an empty list if no images found

# %%
# from pydantic import BaseModel, Field
# from typing import Optional, List





# # Define Pydantic Models
# class ImageSearchInput(BaseModel):
#     q: str = Field(description="Search query for the image")
#     num: Optional[int] = Field(10, description="Number of images to return. Default is 10.")
#     safe: Optional[str] = Field("active", description="Safe search setting: active, moderate, or off")


# class ImageSearchInputSchema(BaseModel):
#     params: ImageSearchInput


# # Define Image Search Function
# def image_finder(params: ImageSearchInput) -> List[dict]:
#     """
#     Find images using Google Images via SerpAPI.
#     Returns a list of image results with URLs and metadata.
#     """
#     search_params = {
#         "api_key": SERPAPI_API_KEY,
#         "engine": "google_images",
#         "q": params.q,
#         "num": params.num,
#         "safe": params.safe,
#         "hl": "en",
#         "gl": "pk",
#     }

#     search = serpapi.search(search_params)
#     results = search.data

#     if "images_results" in results:
#         images = results["images_results"]
#         processed_results = [
#             {
#                 "original": img.get("original", ""),
#                 "thumbnail": img.get("thumbnail", ""),
#                 "title": img.get("title", ""),
#                 "source": img.get("source", ""),
#                 "width": img.get("original_width", 0),
#                 "height": img.get("original_height", 0),
#             }
#             for img in images[:params.num]  # Limit results here as well
#         ]
#         return processed_results

#     return []

# Run the Image Search
# if __name__ == "__main__":
#     # Define input parameters
#     search_input = ImageSearchInput(q="Coffee", num=10, safe="active")

#     # Call the function and get image results
#     image_results = image_finder(search_input)

#     # Print results
#     print(f"Number of images found: {len(image_results)}")
#     for i, img in enumerate(image_results, 1):
#         print(f"\nImage {i}:")
#         print(f"Title: {img['title']}")
#         print(f"URL: {img['original']}")
# Out:
# Number of images found: 10
#
# Image 1:
# Title: 60,000+ Best Coffee Photos · 100% Free ...
# URL: https://images.pexels.com/photos/312418/pexels-photo-312418.jpeg?cs=srgb&dl=pexels-chevanon-312418.jpg&fm=jpg
#
# Image 2:
# Title: Coffee - Wikipedia
# URL: https://upload.wikimedia.org/wikipedia/commons/thumb/e/e4/Latte_and_dark_coffee.jpg/1200px-Latte_and_dark_coffee.jpg
#
# Image 3:
# Title: Pros and Cons of drinking coffee ...
# URL: https://www.spectrumhealth.ie/wp-content/uploads/2017/11/steamingcupofcoffeewithspiltcoffeebeans.jpg
#
# Image 4:
# Title: 30,000+ Aesthetic Coffee Pictures ...
# URL: https://plus.unsplash.com/premium_photo-1674327105076-36c4419864cf?fm=jpg&q=60&w=3000&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxzZWFyY2h8MXx8YWVzdGhldGljJTIwY29mZmVlfGVufDB8fDB8fHww
#
# Image 5:
# Title: Types of Coffee and Their Health Benefits
# URL: https://www.health.com/thmb/YXxmAuCsJHtTWvSWPorjVx1F7AQ=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/Health-GettyImages-TypesOfCoffee-b8f6f7382a1443109f74edb1050f9808.jpg
#
# Image 6:
# Title: Stylish Coffee Pics: 10,000+ Free HD ...
# URL: https://cdn.pixabay.com/photo/2022/11/01/05/18/coffee-7561288_640.jpg
#
# Image 7:
# Title: Coffee bean - Wikipedia
# URL: https://upload.wikimedia.org/wikipedia/commons/c/c5/Roasted_coffee_beans.jpg
#
# Image 8:
# Title: Royal Cup Coffee
# URL: https://www.royalcupcoffee.com/sites/default/files/images/blog/AdobeStock_159183621update.jpg
#
# Image 9:
# Title: Learn How To Make Turkish Coffee with ...
# URL: https://foolproofliving.com/wp-content/uploads/2019/03/Turkish-Coffee-Recipe-Image-500x500.jpg
#
# Image 10:
# Title: Hot Coffee | Beaten Coffee (Cafe Style)
# URL: https://www.vegrecipesofindia.com/wp-content/uploads/2018/02/cafe-style-hot-coffee-recipe-1.jpg

# %%
# from langchain_google_genai import ChatGoogleGenerativeAI

# def multiply(a: int, b: int) -> int:
#     """Multiply a and b.

#     Args:
#         a: first int
#         b: second int
#     """
#     return a * b

# # This will be a tool
# def add(a: int, b: int) -> int:
#     """Adds a and b.

#     Args:
#         a: first int
#         b: second int
#     """
#     return a + b

# def divide(a: int, b: int) -> float:
#     """Divide a and b.

#     Args:
#         a: first int
#         b: second int
#     """
#     return a / b

# tools = [add, multiply, divide]
# llm_with_tools = llm.bind_tools(tools)

# %%
# from langchain_community.tools.tavily_search import TavilySearchResults
# from pydantic import BaseModel



# tool = TavilySearchResults(max_results=2)
tools = [hotels_finder,image_finder]
llm_with_tools = llm.bind_tools(tools)

# %%
llm_with_tools
# Out:
# RunnableBinding(bound=ChatOpenAI(client=<openai.resources.chat.completions.Completions object at 0x7d57fa0e1850>, async_client=<openai.resources.chat.completions.AsyncCompletions object at 0x7d57f16b6810>, root_client=<openai.OpenAI object at 0x7d57f1754750>, root_async_client=<openai.AsyncOpenAI object at 0x7d57f065a690>, model_name='gpt-4o-mini', model_kwargs={}, openai_api_key=SecretStr('**********')), kwargs={'tools': [{'type': 'function', 'function': {'name': 'hotels_finder', 'description': 'Find hotels using the Google Hotels engine.\n\nReturns:\n    dict: Hotel search results.', 'parameters': {'properties': {'params': {'properties': {'q': {'description': 'Location of the hotel', 'type': 'string'}, 'check_in_date': {'description': 'Check-in date. The format is YYYY-MM-DD. e.g. 2024-06-22', 'type': 'string'}, 'check_out_date': {'description': 'Check-out date. The format is YYYY-MM-DD. e.g. 2024-06-28', 'type': 'string'}, 'sort_by': {'anyOf': [{'type': 'string'}, {'type': 'null'}], 'default': 8, 'description': 'Parameter is used for sorting the results. Default is sort by highest rating'}, 'adults': {'anyOf': [{'type': 'integer'}, {'type': 'null'}], 'default': 1, 'description': 'Number of adults. Default to 1.'}, 'children': {'anyOf': [{'type': 'integer'}, {'type': 'null'}], 'default': 0, 'description': 'Number of children. Default to 0.'}, 'rooms': {'anyOf': [{'type': 'integer'}, {'type': 'null'}], 'default': 1, 'description': 'Number of rooms. Default to 1.'}, 'hotel_class': {'anyOf': [{'type': 'string'}, {'type': 'null'}], 'default': None, 'description': 'Parameter defines to include only certain hotel class in the results. for example- 2,3,4'}}, 'required': ['q', 'check_in_date', 'check_out_date'], 'type': 'object'}}, 'required': ['params'], 'type': 'object'}}}, {'type': 'function', 'function': {'name': 'image_finder', 'description': 'Find images using Google Images via SerpAPI.\nReturns a list of image results with URLs and metadata.', 'parameters': {'properties': {'params': {'properties': {'q': {'description': 'Search query for the image', 'type': 'string'}, 'safe': {'anyOf': [{'type': 'string'}, {'type': 'null'}], 'default': 'active', 'description': 'Safe search setting: active, moderate, or off'}}, 'required': ['q'], 'type': 'object'}}, 'required': ['params'], 'type': 'object'}}}]}, config={}, config_factories=[])

# %%
llm_with_tools.kwargs
# Out:
# {'tools': [{'type': 'function',
#    'function': {'name': 'hotels_finder',
#     'description': 'Find hotels using the Google Hotels engine.\n\nReturns:\n    dict: Hotel search results.',
#     'parameters': {'properties': {'params': {'properties': {'q': {'description': 'Location of the hotel',
#          'type': 'string'},
#         'check_in_date': {'description': 'Check-in date. The format is YYYY-MM-DD. e.g. 2024-06-22',
#          'type': 'string'},
#         'check_out_date': {'description': 'Check-out date. The format is YYYY-MM-DD. e.g. 2024-06-28',
#          'type': 'string'},
#         'sort_by': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#          'default': 8,
#          'description': 'Parameter is used for sorting the results. Default is sort by highest rating'},
#         'adults': {'anyOf': [{'type': 'integer'}, {'type': 'null'}],
#          'default': 1,
#          'description': 'Number of adults. Default to 1.'},
#         'children': {'anyOf': [{'type': 'integer'}, {'type': 'null'}],
#          'default': 0,
#          'description': 'Number of children. Default to 0.'},
#         'rooms': {'anyOf': [{'type': 'integer'}, {'type': 'null'}],
#          'default': 1,
#          'description': 'Number of rooms. Default to 1.'},
#         'hotel_class': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#          'default': None,
#          'description': 'Parameter defines to include only certain hotel class in the results. for example- 2,3,4'}},
#        'required': ['q', 'check_in_date', 'check_out_date'],
#        'type': 'object'}},
#      'required': ['params'],
#      'type': 'object'}}},
#   {'type': 'function',
#    'function': {'name': 'image_finder',
#     'description': 'Find images using Google Images via SerpAPI.\nReturns a list of image results with URLs and metadata.',
#     'parameters': {'properties': {'params': {'properties': {'q': {'description': 'Search query for the image',
#          'type': 'string'},
#         'safe': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#          'default': 'active',
#          'description': 'Safe search setting: active, moderate, or off'}},
#        'required': ['q'],
#        'type': 'object'}},
#      'required': ['params'],
#      'type': 'object'}}}]}

# %%
from langgraph.graph import MessagesState
from langchain_core.messages import HumanMessage, SystemMessage
import datetime
import operator

CURRENT_YEAR = datetime.datetime.now().year

# sys_msg = SystemMessage(content=get_system_prompt(state))
def assistant(state: AgentState)->AgentState:
    system_prompt = SystemMessage(content=get_system_prompt(state))
    # messages = [system_prompt] + state['messages']
    # # messages = state['messages']
    # response = llm_with_tools.invoke(messages)
    # # response = llm.invoke(messages)
    # return {"messages": [response]}
    print("state",[system_prompt] + state["messages"])
    return {"messages": [llm_with_tools.invoke([system_prompt] + state["messages"])]}


# # Node
# def assistant(state: AgentState) -> AgentState:
#    return {"messages": [llm_with_tools.invoke([sys_msg] + state["messages"])]}

# %%
from langgraph.graph import START, StateGraph
from langgraph.prebuilt import tools_condition
from langgraph.prebuilt import ToolNode
from IPython.display import Image, display
from langgraph.graph.state import CompiledStateGraph

# Graph
builder: StateGraph = StateGraph(AgentState)

# Define nodes: these do the work
builder.add_node("assistant", assistant)
builder.add_node("tools", ToolNode(tools))

# Define edges: these determine how the control flow moves
builder.add_edge(START, "assistant")
builder.add_conditional_edges(
    "assistant",
    # If the latest message (result) from assistant is a tool call -> tools_condition routes to tools
    # If the latest message (result) from assistant is a not a tool call -> tools_condition routes to END
    tools_condition,
)
builder.add_edge("tools", "assistant")
react_graph: CompiledStateGraph = builder.compile()

# Show
display(Image(react_graph.get_graph(xray=True).draw_mermaid_png()))

# %%
initial_state = {
    "messages": [HumanMessage(content="Plan my trip to Pakistan")],
    "budget": 5000.0,
    "interests": ["sightseeing", "local cuisine"],
    "companions": 2,
    "city": "Skardu",
    "days": 7,
    "travel_date": "2025-10-03",
    "itinerary": []
}

# %%
config1 = {"configurable": {"thread_id": "1"}}

# %%
# Specify an input
# messages = [HumanMessage(content="Plan my trip to Pakistan")]

# Run
messages = react_graph.invoke(initial_state,config1)
print("\n[FINAL RESPONSE]\n",messages)
for m in messages['messages']:
    m.pretty_print()
# Out:
# state [SystemMessage(content='You are a smart travel assistant. Create a detailed itinerary in JSON format considering:\n    - Budget: $5000.0\n    - Travel Interests: sightseeing, local cuisine\n    - Companions: 2 people\n    - Destination: Skardu\n    - Duration: 7 days\n    - Travel Date: 2025-10-03\n\n    Use the hotels_finder tool to get hotel information and the image_finder tool to get high-quality images for activities and locations.\n    For each activity or location, use the image_finder tool to search for relevant images. Choose the best image that represents the location or activity.\n\n    The response should be a valid JSON object with the following structure:\n    {\n        "trip_details": {\n            "destination": string,\n            "duration": number,\n            "travel_date": string,\n            "companions": number,\n            "budget": number,\n            "interests": string[]\n        },\n        "daily_itinerary": [\n            {\n                "day": number,\n                "date": string,\n                "day_title": string,  # e.g., "Cultural Tour", "Arrival Day", "Adventure Day"\n                "description": string,  # Brief description of the day\'s theme and activities\n                "hotel": {\n                    "name": string,\n                    "price": number,\n                    "rating": number,\n                    "reviews": number,\n                    "image_url": string,\n                    "booking_url": string\n                },\n                "transportation": {\n                    "type": string,\n                    "cost": number\n                },\n                "meals": [\n                    {\n                        "type": string,\n                        "venue": string,\n                        "cost": number,\n                        "image_url": string\n                    }\n                ],\n                "activities": [\n                    {\n                        "name": string,\n                        "description": string,\n                        "cost": number,\n                        "image_url": string,\n                        "location_images": [\n                            {\n                                "url": string,\n                                "title": string,\n                                "source": string\n                            }\n                        ]\n                    }\n                ],\n                "daily_cost_breakdown": {\n                    "hotel": number,\n                    "transportation": number,\n                    "food": number,\n                    "activities": number,\n                    "total": number\n                }\n            }\n        ],\n        "cost_summary": {\n            "daily_totals": [\n                {\n                    "day": number,\n                    "amount": number\n                }\n            ],\n            "total_cost": number,\n            "remaining_budget": number\n        }\n    }\n\n    For each activity:\n    1. Use image_finder to get relevant images of the location/activity\n    2. Include multiple images in the location_images array\n    3. Ensure all image URLs are valid and accessible\n\n    For each day:\n    1. Provide a meaningful day_title that describes the theme (e.g., "Cultural Tour", "Adventure Day")\n    2. Include a brief description explaining the day\'s focus and highlights\n    3. Break down costs into categories (hotel, transportation, food, activities)\n    4. Calculate and include the daily total\n\n    In the cost_summary:\n    1. List the total cost for each day\n    2. Calculate the total trip cost\n    3. Show the remaining budget from the original amount\n    ', additional_kwargs={}, response_metadata={}), HumanMessage(content='Plan my trip to Pakistan', additional_kwargs={}, response_metadata={}, id='e50bfc14-2b05-4866-9650-fe24304114fc')]
# WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithAuthError: Authentication failed for https://api.smith.langchain.com/runs/multipart. HTTPError('401 Client Error: Unauthorized for url: https://api.smith.langchain.com/runs/multipart', '{"detail":"Invalid token"}')
# calling...
# calling again...
# hotels results {'search_metadata': {'id': '679f4b4d133bff5ef51b1837', 'status': 'Success', 'json_endpoint': 'https://serpapi.com/searches/6457112189961902/679f4b4d133bff5ef51b1837.json', 'created_at': '2025-02-02 10:39:09 UTC', 'processed_at': '2025-02-02 10:39:09 UTC', 'google_hotels_url': 'https://www.google.com/_/TravelFrontendUi/data/batchexecute?rpcids=AtySUc&source-path=/travel/search&hl=en&gl=pk&rt=c&soc-app=162&soc-platform=1&soc-device=1', 'raw_html_file': 'https://serpapi.com/searches/6457112189961902/679f4b4d133bff5ef51b1837.html', 'prettify_html_file': 'https://serpapi.com/searches/6457112189961902/679f4b4d133bff5ef51b1837.prettify', 'total_time_taken': 1.03}, 'search_parameters': {'engine': 'google_hotels', 'q': 'Skardu', 'gl': 'pk', 'hl': 'en', 'currency': 'PKR', 'check_in_date': '2025-10-03', 'check_out_date': '2025-10-10', 'adults': 2, 'children': 0, 'sort_by': '8'}, 'search_information': {'total_results': 279}, 'properties': [{'type': 'hotel', 'name': 'The Que Skardu', 'gps_coordinates': {'latitude': 35.4430589, 'longitude': 75.45204890000001}, 'nearby_places': [{'name': 'Upper Kachura Lake', 'transportations': [{'type': 'Walking', 'duration': '1 min'}]}, {'name': 'Islamabad International Airport', 'transportations': [{'type': 'Taxi', 'duration': '14 hr 1 min'}]}, {'name': 'Ali Zada Hotel and Restaurant Upper kachurara', 'transportations': [{'type': 'Walking', 'duration': '1 min'}]}], 'images': [{'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipMel55XpUZvKEOfY3PViwlBRY9DSQFDSuMlgt9Z=s287-w287-h192-n-k-no-v1', 'original_image': 'https://lh5.googleusercontent.com/p/AF1QipMel55XpUZvKEOfY3PViwlBRY9DSQFDSuMlgt9Z=s10000'}, {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPiJeagtgthR_AH48tkZHAvaliAhZbjjwRthMoH=s287-w287-h192-n-k-no-v1', 'original_image': 'https://lh5.googleusercontent.com/p/AF1QipPiJeagtgthR_AH48tkZHAvaliAhZbjjwRthMoH=s10000'}, {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipP1Ct0dFF74cjtsSOKtl45SGGzF8pWrHByTX7Oi=s287-w287-h192-n-k-no-v1', 'original_image': 'https://lh5.googleusercontent.com/p/AF1QipP1Ct0dFF74cjtsSOKtl45SGGzF8pWrHByTX7Oi=s10000'}, {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipMd38_qXmf9yhiHzLQlj7s3_KrUE01d5UBTuJ9t=s287-w287-h192-n-k-no-v1', 'original_image': 'https://lh5.googleusercontent.com/p/AF1QipMd38_qXmf9yhiHzLQlj7s3_KrUE01d5UBTuJ9t=s10000'}, {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPMyRyRDrQ669iKyAzWzvzPNgILu6BfUyAb_5qf=s287-w287-h192-n-k-no-v1', 'original_image': 'https://lh5.googleusercontent.com/p/AF1QipPMyRyRDrQ669iKyAzWzvzPNgILu6BfUyAb_5qf=s10000'}, {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipOue8bnL4eO2p_Vmt8LDxL_9vuCEp4NIU-Zna9x=s287-w287-h192-n-k-no-v1', 'original_image': 'https://lh5.googleusercontent.com/p/AF1QipOue8bnL4eO2p_Vmt8LDxL_9vuCEp4NIU-Zna9x=s10000'}, {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipMTUrhdQveQGsDmzUdwBcL6WoE4rn1QOwaH1kDM=s287-w287-h192-n-k-no-v1', 'original_image': 'https://lh5.googleusercontent.com/p/AF1QipMTUrhdQveQGsDmzUdwBcL6WoE4rn1QOwaH1kDM=s10000'}, {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipM9kIAD8-kV6SRhQ20z_sh71zf7VvXnhHcKKC1h=s287-w287-h192-n-k-no-v1', 'original_image': 'https://lh5.googleusercontent.com/p/AF1QipM9kIAD8-kV6SRhQ20z_sh71zf7VvXnhHcKKC1h=s10000'}, {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipMf26QdNjxGhecq-eF9l7QaD3z6Z2df4-KDOa75=s287-w287-h192-n-k-no-v1', 'original_image': 'https://lh5.googleusercontent.com/p/AF1QipMf26QdNjxGhecq-eF9l7QaD3z6Z2df4-KDOa75=s10000'}], 'overall_rating': 5, 'reviews': 275, 'ratings': [{'stars': 5, 'count': 272}, {'stars': 4, 'count': 3}, {'stars': 3, 'count': 0}, {'stars': 2, 'count': 0}, {'stars': 1, 'count': 0}], 'location_rating': 3.3, 'reviews_breakdown': [{'name': 'Dining', 'description': 'Food and Beverage', 'total_mentioned': 38, 'positive': 38, 'negative': 0, 'neutral': 0}, {'name': 'Breakfast', 'description': 'Breakfast', 'total_mentioned': 16, 'positive': 16, 'negative': 0, 'neutral': ...
# WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithAuthError: Authentication failed for https://api.smith.langchain.com/runs/multipart. HTTPError('401 Client Error: Unauthorized for url: https://api.smith.langchain.com/runs/multipart', '{"detail":"Invalid token"}')
# WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithAuthError: Authentication failed for https://api.smith.langchain.com/runs/multipart. HTTPError('401 Client Error: Unauthorized for url: https://api.smith.langchain.com/runs/multipart', '{"detail":"Invalid token"}')
# state [SystemMessage(content='You are a smart travel assistant. Create a detailed itinerary in JSON format considering:\n    - Budget: $5000.0\n    - Travel Interests: sightseeing, local cuisine\n    - Companions: 2 people\n    - Destination: Skardu\n    - Duration: 7 days\n    - Travel Date: 2025-10-03\n\n    Use the hotels_finder tool to get hotel information and the image_finder tool to get high-quality images for activities and locations.\n    For each activity or location, use the image_finder tool to search for relevant images. Choose the best image that represents the location or activity.\n\n    The response should be a valid JSON object with the following structure:\n    {\n        "trip_details": {\n            "destination": string,\n            "duration": number,\n            "travel_date": string,\n            "companions": number,\n            "budget": number,\n            "interests": string[]\n        },\n        "daily_itinerary": [\n            {\n                "day": number,\n                "date": string,\n                "day_title": string,  # e.g., "Cultural Tour", "Arrival Day", "Adventure Day"\n                "description": string,  # Brief description of the day\'s theme and activities\n                "hotel": {\n                    "name": string,\n                    "price": number,\n                    "rating": number,\n                    "reviews": number,\n                    "image_url": string,\n                    "booking_url": string\n                },\n                "transportation": {\n                    "type": string,\n                    "cost": number\n                },\n                "meals": [\n                    {\n                        "type": string,\n                        "venue": string,\n                        "cost": number,\n                        "image_url": string\n                    }\n                ],\n                "activities": [\n                    {\n                        "name": string,\n                        "description": string,\n                        "cost": number,\n                        "image_url": string,\n                        "location_images": [\n                            {\n                                "url": string,\n                                "title": string,\n                                "source": string\n                            }\n                        ]\n                    }\n                ],\n                "daily_cost_breakdown": {\n                    "hotel": number,\n                    "transportation": number,\n                    "food": number,\n                    "activities": number,\n                    "total": number\n                }\n            }\n        ],\n        "cost_summary": {\n            "daily_totals": [\n                {\n                    "day": number,\n                    "amount": number\n                }\n            ],\n            "total_cost": number,\n            "remaining_budget": number\n        }\n    }\n\n    For each activity:\n    1. Use image_finder to get relevant images of the location/activity\n    2. Include multiple images in the location_images array\n    3. Ensure all image URLs are valid and accessible\n\n    For each day:\n    1. Provide a meaningful day_title that describes the theme (e.g., "Cultural Tour", "Adventure Day")\n    2. Include a brief description explaining the day\'s focus and highlights\n    3. Break down costs into categories (hotel, transportation, food, activities)\n    4. Calculate and include the daily total\n\n    In the cost_summary:\n    1. List the total cost for each day\n    2. Calculate the total trip cost\n    3. Show the remaining budget from the original amount\n    ', additional_kwargs={}, response_metadata={}), HumanMessage(content='Plan my trip to Pakistan', additional_kwargs={}, response_metadata={}, id='e50bfc14-2b05-4866-9650-fe24304114fc'), AIMessage(content='', additional_kwargs={'tool_cal ...
# WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithAuthError: Authentication failed for https://api.smith.langchain.com/runs/multipart. HTTPError('401 Client Error: Unauthorized for url: https://api.smith.langchain.com/runs/multipart', '{"detail":"Invalid token"}')
# [FINAL RESPONSE]
#  {'messages': [HumanMessage(content='Plan my trip to Pakistan', additional_kwargs={}, response_metadata={}, id='e50bfc14-2b05-4866-9650-fe24304114fc'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_bfBOPRZdS0EYK2KcmhcvmuSe', 'function': {'arguments': '{"params": {"q": "Skardu", "check_in_date": "2025-10-03", "check_out_date": "2025-10-10", "sort_by": "8", "adults": 2}}', 'name': 'hotels_finder'}, 'type': 'function'}, {'id': 'call_Ty6HgRwHSupJFbaNdA8mx2pI', 'function': {'arguments': '{"params": {"q": "Skardu sightseeing", "safe": "active"}}', 'name': 'image_finder'}, 'type': 'function'}, {'id': 'call_ZM9MuXux2FKIuIzjTPwScC1f', 'function': {'arguments': '{"params": {"q": "Local cuisine in Skardu", "safe": "active"}}', 'name': 'image_finder'}, 'type': 'function'}, {'id': 'call_sMfGAiFEPwt3HP92fU7l7JLm', 'function': {'arguments': '{"params": {"q": "Kachura Lake", "safe": "active"}}', 'name': 'image_finder'}, 'type': 'function'}, {'id': 'call_Gc411vyEtdW6MrHVk50rQY7H', 'function': {'arguments': '{"params": {"q": "Deosai National Park", "safe": "active"}}', 'name': 'image_finder'}, 'type': 'function'}, {'id': 'call_81GPjxcJCraCqCs9JXMnvDTl', 'function': {'arguments': '{"params": {"q": "Shigar Fort", "safe": "active"}}', 'name': 'image_finder'}, 'type': 'function'}, {'id': 'call_jSBNBBusmDJjgntEKa3b4RB3', 'function': {'arguments': '{"params": {"q": "Skardu culture", "safe": "active"}}', 'name': 'image_finder'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 212, 'prompt_tokens': 1008, 'total_tokens': 1220, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_72ed7ab54c', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-6abe104d-388d-40f1-bddc-3d90d92ac6be-0', tool_calls=[{'name': 'hotels_finder', 'args': {'params': {'q': 'Skardu', 'check_in_date': '2025-10-03', 'check_out_date': '2025-10-10', 'sort_by': '8', 'adults': 2}}, 'id': 'call_bfBOPRZdS0EYK2KcmhcvmuSe', 'type': 'tool_call'}, {'name': 'image_finder', 'args': {'params': {'q': 'Skardu sightseeing', 'safe': 'active'}}, 'id': 'call_Ty6HgRwHSupJFbaNdA8mx2pI', 'type': 'tool_call'}, {'name': 'image_finder', 'args': {'params': {'q': 'Local cuisine in Skardu', 'safe': 'active'}}, 'id': 'call_ZM9MuXux2FKIuIzjTPwScC1f', 'type': 'tool_call'}, {'name': 'image_finder', 'args': {'params': {'q': 'Kachura Lake', 'safe': 'active'}}, 'id': 'call_sMfGAiFEPwt3HP92fU7l7JLm', 'type': 'tool_call'}, {'name': 'image_finder', 'args': {'params': {'q': 'Deosai National Park', 'safe': 'active'}}, 'id': 'call_Gc411vyEtdW6MrHVk50rQY7H', 'type': 'tool_call'}, {'name': 'image_finder', 'args': {'params': {'q': 'Shigar Fort', 'safe': 'active'}}, 'id': 'call_81GPjxcJCraCqCs9JXMnvDTl', 'type': 'tool_call'}, {'name': 'image_finder', 'args': {'params': {'q': 'Skardu culture', 'safe': 'active'}}, 'id': 'call_jSBNBBusmDJjgntEKa3b4RB3', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1008, 'output_tokens': 212, 'total_tokens': 1220, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='[{"type": "hotel", "name": "The Que Skardu", "gps_coordinates": {"latitude": 35.4430589, "longitude": 75.45204890000001}, "nearby_places": [{"name": "Upper Kachura Lake", "transportations": [{"type": "Walking", "duration": "1 min"}]}, {"name": "Islamabad International Airport", "transportations": [{"type": "Taxi", "duration": "14 hr 1 min"}]}, {"name": "Ali Zada Hotel and Restaurant Upper kachurara", "transportations": [{"type": "Walking", "duration": "1 min"}]}], "images": [{"thumbnail": "https://lh5.googleusercontent.com/p/AF1QipMel55XpUZvKEOfY3PViwlBRY9DSQFDSuMlgt9Z=s287-w287-h192-n-k-no-v1", "original_image": "https://lh5.googleusercontent.com/p/AF1QipMel55 ...
# ================================ Human Message =================================
#
# Plan my trip to Pakistan
# ================================== Ai Message ==================================
# Tool Calls:
#   hotels_finder (call_bfBOPRZdS0EYK2KcmhcvmuSe)
#  Call ID: call_bfBOPRZdS0EYK2KcmhcvmuSe
#   Args:
#     params: {'q': 'Skardu', 'check_in_date': '2025-10-03', 'check_out_date': '2025-10-10', 'sort_by': '8', 'adults': 2}
#   image_finder (call_Ty6HgRwHSupJFbaNdA8mx2pI)
#  Call ID: call_Ty6HgRwHSupJFbaNdA8mx2pI
#   Args:
#     params: {'q': 'Skardu sightseeing', 'safe': 'active'}
#   image_finder (call_ZM9MuXux2FKIuIzjTPwScC1f)
#  Call ID: call_ZM9MuXux2FKIuIzjTPwScC1f
#   Args:
#     params: {'q': 'Local cuisine in Skardu', 'safe': 'active'}
#   image_finder (call_sMfGAiFEPwt3HP92fU7l7JLm)
#  Call ID: call_sMfGAiFEPwt3HP92fU7l7JLm
#   Args:
#     params: {'q': 'Kachura Lake', 'safe': 'active'}
#   image_finder (call_Gc411vyEtdW6MrHVk50rQY7H)
#  Call ID: call_Gc411vyEtdW6MrHVk50rQY7H
#   Args:
#     params: {'q': 'Deosai National Park', 'safe': 'active'}
#   image_finder (call_81GPjxcJCraCqCs9JXMnvDTl)
#  Call ID: call_81GPjxcJCraCqCs9JXMnvDTl
#   Args:
#     params: {'q': 'Shigar Fort', 'safe': 'active'}
#   image_finder (call_jSBNBBusmDJjgntEKa3b4RB3)
#  Call ID: call_jSBNBBusmDJjgntEKa3b4RB3
#   Args:
#     params: {'q': 'Skardu culture', 'safe': 'active'}
# ================================= Tool Message =================================
# Name: hotels_finder
#
# [{"type": "hotel", "name": "The Que Skardu", "gps_coordinates": {"latitude": 35.4430589, "longitude": 75.45204890000001}, "nearby_places": [{"name": "Upper Kachura Lake", "transportations": [{"type": "Walking", "duration": "1 min"}]}, {"name": "Islamabad International Airport", "transportations": [{"type": "Taxi", "duration": "14 hr 1 min"}]}, {"name": "Ali Zada Hotel and Restaurant Upper kachurara", "transportations": [{"type": "Walking", "duration": "1 min"}]}], "images": [{"thumbnail": "https://lh5.googleusercontent.com/p/AF1QipMel55XpUZvKEOfY3PViwlBRY9DSQFDSuMlgt9Z=s287-w287-h192-n-k-no-v1", "original_image": "https://lh5.googleusercontent.com/p/AF1QipMel55XpUZvKEOfY3PViwlBRY9DSQFDSuMlgt9Z=s10000"}, {"thumbnail": "https://lh5.googleusercontent.com/p/AF1QipPiJeagtgthR_AH48tkZHAvaliAhZbjjwRthMoH=s287-w287-h192-n-k-no-v1", "original_image": "https://lh5.googleusercontent.com/p/AF1QipPiJeagtgthR_AH48tkZHAvaliAhZbjjwRthMoH=s10000"}, {"thumbnail": "https://lh5.googleusercontent.com/p/AF1QipP1Ct0dFF74cjtsSOKtl45SGGzF8pWrHByTX7Oi=s287-w287-h192-n-k-no-v1", "original_image": "https://lh5.googleusercontent.com/p/AF1QipP1Ct0dFF74cjtsSOKtl45SGGzF8pWrHByTX7Oi=s10000"}, {"thumbnail": "https://lh5.googleusercontent.com/p/AF1QipMd38_qXmf9yhiHzLQlj7s3_KrUE01d5UBTuJ9t=s287-w287-h192-n-k-no-v1", "original_image": "https://lh5.googleusercontent.com/p/AF1QipMd38_qXmf9yhiHzLQlj7s3_KrUE01d5UBTuJ9t=s10000"}, {"thumbnail": "https://lh5.googleusercontent.com/p/AF1QipPMyRyRDrQ669iKyAzWzvzPNgILu6BfUyAb_5qf=s287-w287-h192-n-k-no-v1", "original_image": "https://lh5.googleusercontent.com/p/AF1QipPMyRyRDrQ669iKyAzWzvzPNgILu6BfUyAb_5qf=s10000"}, {"thumbnail": "https://lh5.googleusercontent.com/p/AF1QipOue8bnL4eO2p_Vmt8LDxL_9vuCEp4NIU-Zna9x=s287-w287-h192-n-k-no-v1", "original_image": "https://lh5.googleusercontent.com/p/AF1QipOue8bnL4eO2p_Vmt8LDxL_9vuCEp4NIU-Zna9x=s10000"}, {"thumbnail": "https://lh5.googleusercontent.com/p/AF1QipMTUrhdQveQGsDmzUdwBcL6WoE4rn1QOwaH1kDM=s287-w287-h192-n-k-no-v1", "original_image": "https://lh5.googleusercontent.com/p/AF1QipMTUrhdQveQGsDmzUdwBcL6WoE4rn1QOwaH1kDM=s10000"}, {"thumbnail": "https://lh5.googleusercontent.com/p/AF1QipM9kIAD8-kV6SRhQ20z_sh71zf7VvXnhHcKKC1h=s287-w287-h192-n-k-no-v1", "original_image": "https://lh5.googleusercontent.com/p/AF1QipM9kIAD8-kV6SRhQ20z_sh71zf7VvXnhHcKKC1h=s10000"}, {"thumbnail": "https://lh5.googleusercontent.com/p/AF1QipMf26QdNjxGhecq-eF9l7QaD3z6Z2df4-KDOa75=s287-w287-h192-n-k-no-v1", "original_image": "https://lh5.googleusercontent.com/p/AF1QipMf26QdNjxGhecq-eF9l7QaD3z6Z2df4-KDOa75=s10000"}], "overall_rating": 5, "reviews": 275, "ratings": [{"stars": 5, "count": 272}, {"stars": 4, "count": 3}, {"stars": 3, "count": 0}, {"stars": 2, "count": 0}, {"stars": 1, "count": 0}], "location_rating": 3.3, "reviews_breakdown": [{"name": "Dining", "description": "Food and Beverage", "total_mentioned": 38, "positive": 38, "negative": 0, "neutral": 0}, {"name": "Breakfast", "description": "Breakfast", "total_mentioned": 16, "positive": 16, "negative": 0, "neutral": 0}, {"name": "Nature", "description": "Nature and outdoor activities", "total_mentioned": 12, "positive": 12, "negative": 0, "neutral": 0}, {"name": "Service", "description": "Service", "total_mentioned": 35, "positive": 35, "negative": 0, "neutral": 0}, {"name": "Atmosphere", "description": "Atmosphere", "total_mentioned": 15, "positive": 15, "negative": 0, "neutral": 0}, {"name": "Location", "description": "Location", "total_mentioned": 13, "positive": 12, "negative": 0, "neutral": 1}], "property_token": "ChoIz4y-o_uSy5SGARoNL2cvMTFscDd5aGh4NxAB", "serpapi_property_details_link": "https://serpapi.com/search.json?adults=2&check_in_date=2025-10-03&check_out_date=2025-10-10&children=0&currency=PKR&engine=google_hotels&gl=pk&hl=en&property_token=ChoIz4y-o_uSy5SGARoNL2cvMTFscDd5aGh4NxAB&q=Skardu&sort_by=8"}, {"type": "hotel", "name": "Dirleh Hotel", "link": "http://dirleh.com/", "gps_coordinates": {"latitude": 35.2784815, "longitude": 75.633426 ...
# ================================= Tool Message =================================
# Name: image_finder
#
# [{"original": "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/0d/39/26/f2/upper-kachura-lake-is.jpg?w=1200&h=700&s=1", "thumbnail": "https://serpapi.com/searches/679f57ec92d1c70094ace699/images/f0833536787022a3a1d628a898728795ff88932ac89464bf24eabba8353e9e51.jpeg", "title": "THE 15 BEST Things to Do in Skardu ...", "source": "Tripadvisor", "width": 1200, "height": 700}, {"original": "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/0f/30/78/2c/rama-meadows.jpg?w=500&h=400&s=1", "thumbnail": "https://serpapi.com/searches/679f57ec92d1c70094ace699/images/f0833536787022a3b0265152f56900a51c41ba313d970a0d75a4b89382fcf77a.jpeg", "title": "THE 15 BEST Things to Do in Skardu ...", "source": "Tripadvisor", "width": 500, "height": 400}, {"original": "https://visitgilgitbaltistan.gov.pk/storage/images/EgzRNEiwXoQdYYriBJZ4pfaOqAZtEE-metaU2hhbmdyaWxhLF9Mb3dlcl9LYWNodXJhX0xha2UuanBn-.jpg", "thumbnail": "https://serpapi.com/searches/679f57ec92d1c70094ace699/images/f0833536787022a346e8a876a87fd6fed9051e0ffdd503ed66101c3f6cd04ad1.jpeg", "title": "Tourism, Sports, Culture, Archaeology ...", "source": "Tourism, Sports, Culture, Archaeology & Museums Department | District Tours", "width": 1024, "height": 678}, {"original": "https://www.imusafir.pk/wp-content/uploads/2023/09/skardu-2-1200x900.jpeg", "thumbnail": "https://serpapi.com/searches/679f57ec92d1c70094ace699/images/f0833536787022a342dd787cbe6a5c165246103915f89bc07807c5a128dbc85e.jpeg", "title": "5 Days Skardu By Air Tour Package ...", "source": "iMusafir.pk", "width": 1200, "height": 900}, {"original": "https://visitinpakistan.com/wp-content/uploads/2020/02/featured-image-1024x458.jpg", "thumbnail": "https://serpapi.com/searches/679f57ec92d1c70094ace699/images/f0833536787022a30d4e25dab8e6ddf39349c1a4e2b0aa6928c52e822ec36119.jpeg", "title": "in Skardu Gilgit Baltistan, Pakistan", "source": "Visit In Pakistan", "width": 1024, "height": 458}, {"original": "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/14/57/71/d6/img-20180823-220750-705.jpg?w=500&h=-1&s=1", "thumbnail": "https://serpapi.com/searches/679f57ec92d1c70094ace699/images/f0833536787022a3ea57670458257398381e4e40b8d1272b31ede79697131e98.jpeg", "title": "THE 15 BEST Things to Do in Skardu ...", "source": "Tripadvisor", "width": 500, "height": 390}, {"original": "https://www.apricottours.pk/wp-content/uploads/2023/11/sim-la-56.png", "thumbnail": "https://serpapi.com/searches/679f57ec92d1c70094ace699/images/f0833536787022a3512dc9c469b517fa9c0c6f5ed110bf307f66c541ca158ca1.jpeg", "title": "Top 60 Things to do in Skardu - 2024-25 ...", "source": "Apricot Tours", "width": 1024, "height": 683}, {"original": "https://www.natureadventureclub.pk/wp-content/uploads/2024/09/Shagrilla-Resort-Skardu.jpg", "thumbnail": "https://serpapi.com/searches/679f57ec92d1c70094ace699/images/f0833536787022a3900de99f45aa85e1cdb8dfffe7067e01c79d127575ef732f.jpeg", "title": "Tourist Places to Visit in Skardu ...", "source": "Nature Adventure Club", "width": 2048, "height": 1536}, {"original": "https://thekarakoram.com.pk/wp-content/uploads/2023/05/skardu-shangrila-1024x687.jpg", "thumbnail": "https://serpapi.com/searches/679f57ec92d1c70094ace699/images/f0833536787022a39c37a79986a60f1b9ebb77cc0f09765cf09dff74e431ab68.jpeg", "title": "15 Best Places to Visit in Skardu - The ...", "source": "The Karakoram", "width": 1024, "height": 687}, {"original": "https://pakistantourntravel.com/wp-content/uploads/2018/05/Shangri-La-Lake-1.jpg", "thumbnail": "https://serpapi.com/searches/679f57ec92d1c70094ace699/images/f0833536787022a3396a8b5e8f622d0c83f91494beb5c47f312a019495e355d6.jpeg", "title": "Visit In Skardu: Best Top 10 Places Of ...", "source": "Pakistan Tour And Travel", "width": 700, "height": 394}]
# ================================= Tool Message =================================
# Name: image_finder
#
# [{"original": "https://migrationology.com/wp-content/uploads/2018/12/baltistan-food-skardu.jpg", "thumbnail": "https://serpapi.com/searches/679f57ec3027ad96946a46f3/images/589af8674a9eb09c03bed2b3c8f5b7b92b08b84d79eced350c8798df45914e9f.jpeg", "title": "Traditional Baltistan Food - Family ...", "source": "Migrationology", "width": 2200, "height": 1467}, {"original": "https://res.cloudinary.com/www-travelpakistani-com/image/upload/v1680018316/gyaling_food.jpg", "thumbnail": "https://serpapi.com/searches/679f57ec3027ad96946a46f3/images/589af8674a9eb09c47fb5bbe8a4949d84037a694a023e11bc861dcb501328243.jpeg", "title": "Traditional Food", "source": "Travel Pakistani", "width": 1030, "height": 524}, {"original": "https://www.apricottours.pk/wp-content/uploads/2023/12/Chapshoro.jpg", "thumbnail": "https://serpapi.com/searches/679f57ec3027ad96946a46f3/images/589af8674a9eb09c4e51b038c9540a4a06dfca578bdb5ed6665aa461465798d0.jpeg", "title": "30 Best Food in Skardu - 2024-25 ...", "source": "Apricot Tours", "width": 1280, "height": 720}, {"original": "https://i.ytimg.com/vi/9mn8MZF4JWI/hq720.jpg?sqp=-oaymwEhCK4FEIIDSFryq4qpAxMIARUAAAAAGAElAADIQj0AgKJD&rs=AOn4CLDJsO4Y5y7-uM_jq4we3papNZczMA", "thumbnail": "https://serpapi.com/searches/679f57ec3027ad96946a46f3/images/589af8674a9eb09cb963e4a124d4568e71b2834d46009a9bd2cf4121ebe18c92.jpeg", "title": "Pakistani Food in Gilgit-Baltistan ...", "source": "YouTube", "width": 686, "height": 386}, {"original": "https://i.ytimg.com/vi/Qxb_3EpFOiw/maxresdefault.jpg", "thumbnail": "https://serpapi.com/searches/679f57ec3027ad96946a46f3/images/589af8674a9eb09c9d85ab584d6ad6fd510614b040c608e0e6238448e485b4dd.jpeg", "title": "Local DISHES In Baltistan Pakistan ...", "source": "YouTube", "width": 1280, "height": 720}, {"original": "https://res.cloudinary.com/www-travelpakistani-com/image/upload/v1680018315/Harissa.jpg", "thumbnail": "https://serpapi.com/searches/679f57ec3027ad96946a46f3/images/589af8674a9eb09c23084e82360418b821023c9bb686774b97bb39ce0c0951b4.jpeg", "title": "Traditional Food", "source": "Travel Pakistani", "width": 720, "height": 342}, {"original": "https://res.cloudinary.com/www-travelpakistani-com/image/upload/w_900,h_360,c_fill,g_auto,q_30,dpr_1.0,f_auto/blogs/fn6adbko5wiuyn8qbhwr.webp", "thumbnail": "https://serpapi.com/searches/679f57ec3027ad96946a46f3/images/589af8674a9eb09c328a3ef0326f7e6b9eeed60f84e4177a530f3fc966004ab9.jpeg", "title": "Traditional Food", "source": "Travel Pakistani", "width": 900, "height": 360}, {"original": "https://www.apricottours.pk/wp-content/uploads/2023/11/sim-la-35-850x459.png", "thumbnail": "https://serpapi.com/searches/679f57ec3027ad96946a46f3/images/589af8674a9eb09cbee00cd20202d9601438290e9b8667d4aa27b15c632f6b03.jpeg", "title": "30 Best Food in Skardu - 2024-25 ...", "source": "Apricot Tours", "width": 850, "height": 459}, {"original": "https://res.cloudinary.com/www-travelpakistani-com/image/upload/v1680018315/Mul.jpg", "thumbnail": "https://serpapi.com/searches/679f57ec3027ad96946a46f3/images/589af8674a9eb09c0e70dcb097724f250a891f31dc6cc4583e0f0ccbfa0c7b6e.jpeg", "title": "Traditional Food", "source": "Travel Pakistani", "width": 1024, "height": 508}, {"original": "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/19/50/4c/86/trip-type-family-couple.jpg?w=600&h=-1&s=1", "thumbnail": "https://serpapi.com/searches/679f57ec3027ad96946a46f3/images/589af8674a9eb09c3b7235e1e0f8cc7210c36c9fc5c796cb6fe78b9602d839b7.jpeg", "title": "THE 10 BEST Restaurants in Skardu ...", "source": "Tripadvisor", "width": 600, "height": 600}]
# ================================= Tool Message =================================
# Name: image_finder
#
# [{"original": "https://upload.wikimedia.org/wikipedia/commons/5/53/Shangrila_Resorts.jpg", "thumbnail": "https://serpapi.com/searches/679f57eca73b1aa6d9e85174/images/3ff19cd0846470381ca6aba78a7195908f77504b18d954488bf8f5bd2e4eb1a5.jpeg", "title": "Kachura Lake - Wikipedia", "source": "Wikipedia", "width": 3888, "height": 2502}, {"original": "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/0d/39/26/f2/upper-kachura-lake-is.jpg?w=1200&h=-1&s=1", "thumbnail": "https://serpapi.com/searches/679f57eca73b1aa6d9e85174/images/3ff19cd084647038c293b930cc2389bde16b38f58753a0f197fb29555d55bca4.jpeg", "title": "Upper Kachura Lake - All You Need to ...", "source": "Tripadvisor", "width": 1200, "height": 800}, {"original": "https://upload.wikimedia.org/wikipedia/commons/5/5b/Shangrila%2C_Lower_Kachura_Lake.jpg", "thumbnail": "https://serpapi.com/searches/679f57eca73b1aa6d9e85174/images/3ff19cd0846470387eb94d22da0e1cefc2a366d89d967c91c7f3fd55364b2967.jpeg", "title": "Lower Kachura Lake - Wikipedia", "source": "Wikipedia", "width": 4928, "height": 3264}, {"original": "https://www.calamitytravels.com/wp-content/uploads/2022/04/IMG_8236-2-1024x578.jpg", "thumbnail": "https://serpapi.com/searches/679f57eca73b1aa6d9e85174/images/3ff19cd0846470387e540f0ea21eb5071b9e2a701f922f3fb086bee2172c7521.jpeg", "title": "Upper Kachura Lake. Another reason to ...", "source": "Calamity Travels", "width": 1024, "height": 578}, {"original": "https://pyaraskardu.com/wp-content/uploads/2022/12/1280px-Upper_kachura_lake_skardu_baltistan-960x576.jpg", "thumbnail": "https://serpapi.com/searches/679f57eca73b1aa6d9e85174/images/3ff19cd084647038a2a18bc1a9549f93ec79bf98e78cc34808efd3cbf71ea728.jpeg", "title": "Upper Kachura Lake Skardu", "source": "pyara skardu", "width": 960, "height": 576}, {"original": "https://c8.alamy.com/comp/2D0GHHY/lower-kachura-lake-also-known-as-shangrila-lake-is-located-in-kachura-village-in-skardu-city-at-a-height-of-2500-metres-2D0GHHY.jpg", "thumbnail": "https://serpapi.com/searches/679f57eca73b1aa6d9e85174/images/3ff19cd0846470386820f0f0d121f3ddf50830bd93c5c534a114594f7b86de38.jpeg", "title": "Lower Kachura Lake, also known as ...", "source": "Alamy", "width": 1300, "height": 956}, {"original": "https://vepakistan.com/wp-content/uploads/2015/01/Lower-kachura-lake-scaled.jpg", "thumbnail": "https://serpapi.com/searches/679f57eca73b1aa6d9e85174/images/3ff19cd0846470383b914977cf3dba1d5037f5cd67fe38fb45eeddca78837046.jpeg", "title": "Kachura Lake | Vertical Explorers", "source": "Vertical Explorers", "width": 2560, "height": 2560}, {"original": "https://guidetopakistan.pk/wp-content/uploads/2021/04/kachura-2.jpg", "thumbnail": "https://serpapi.com/searches/679f57eca73b1aa6d9e85174/images/3ff19cd084647038b7754b26df976aab09ca675ea02ba8aafaf62acde2f115bf.jpeg", "title": "Kachura Lake: All You Need To Know ...", "source": "Guide to Pakistan", "width": 1280, "height": 960}, {"original": "https://www.calamitytravels.com/wp-content/uploads/2022/04/IMG_8233-1024x578.jpg", "thumbnail": "https://serpapi.com/searches/679f57eca73b1aa6d9e85174/images/3ff19cd0846470389ee33d5a2f3110f41658cd275bcf978f5989e5e31a82fe21.jpeg", "title": "Upper Kachura Lake. Another reason to ...", "source": "Calamity Travels", "width": 1024, "height": 578}, {"original": "https://elands.pk/wp-content/uploads/2023/02/Pasted-1.png", "thumbnail": "https://serpapi.com/searches/679f57eca73b1aa6d9e85174/images/3ff19cd08464703805df46543a570502c36479c5557051097d423374f7f45044.jpeg", "title": "Lower Kachura Lake: A Nature Lover's ...", "source": "elands.pk", "width": 1080, "height": 607}]
# ================================= Tool Message =================================
# Name: image_finder
#
# [{"original": "https://upload.wikimedia.org/wikipedia/commons/7/7b/Deosai_pic_hd.jpg", "thumbnail": "https://serpapi.com/searches/679f57ec8ba25768fc7fa679/images/1a6da710ac2a27c52a51881f81da6f6c08b56f822aa23707d90e4692032cf318.jpeg", "title": "Deosai National Park - Wikipedia", "source": "Wikipedia", "width": 5097, "height": 3398}, {"original": "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/0f/30/78/2c/rama-meadows.jpg?w=1200&h=1200&s=1", "thumbnail": "https://serpapi.com/searches/679f57ec8ba25768fc7fa679/images/1a6da710ac2a27c54e2e76592f8049d97a7dfcad0798b885b5c1c51f20fa0c7d.jpeg", "title": "Deosai National Park - All You Need to ...", "source": "Tripadvisor", "width": 1200, "height": 899}, {"original": "https://elands.pk/deosai-national-park/deosai-national-park-2/", "thumbnail": "https://serpapi.com/searches/679f57ec8ba25768fc7fa679/images/1a6da710ac2a27c5705c8ce607cbc924a68f44cb5ced3dcc49faf0cf6a241bb2.jpeg", "title": "Deosai National Park: A Comprehensive ...", "source": "elands.pk", "width": 992, "height": 660}, {"original": "https://images.squarespace-cdn.com/content/v1/5dfd1ed2eef73319397ce4fe/1591692711059-99VCUQ7VGZMKRCPL8B20/Deosai.jpg", "thumbnail": "https://serpapi.com/searches/679f57ec8ba25768fc7fa679/images/1a6da710ac2a27c57c58213f709d1653d34b26bde1bed718a7012939775b059d.jpeg", "title": "Deosai National Park — The Wander ...", "source": "The Wander Adventures", "width": 1600, "height": 1045}, {"original": "https://visitgilgitbaltistan.gov.pk/storage/images/8yBU3bDvjlndz5hRtPhAbru7EYg73M-metaRGVvc2FpIE5hdGlvbmFsIHBhcmsuanBn-.jpg", "thumbnail": "https://serpapi.com/searches/679f57ec8ba25768fc7fa679/images/1a6da710ac2a27c5ea5bc32e0f3de97d67a37d0903e48118da7d60bf18b5c2ef.jpeg", "title": "Deosai National Park", "source": "Gilgit-Baltistan", "width": 1000, "height": 600}, {"original": "https://lookaside.fbsbx.com/lookaside/crawler/media/?media_id=100080291469177", "thumbnail": "https://serpapi.com/searches/679f57ec8ba25768fc7fa679/images/1a6da710ac2a27c56a8108c0113861a402aa00eadeea5f82e4ea1e5bda011d99.jpeg", "title": "Deosai National Park", "source": "Facebook", "width": 2048, "height": 1365}, {"original": "https://vepakistan.com/wp-content/uploads/2019/04/deosai-1.jpg", "thumbnail": "https://serpapi.com/searches/679f57ec8ba25768fc7fa679/images/1a6da710ac2a27c5ae8a9d2798828dfe98c7819420e1ab17bb6b281ffe04b7a3.jpeg", "title": "Scenic Deosai National Park Guide 2024 ...", "source": "Vertical Explorers", "width": 960, "height": 544}, {"original": "https://www.getout.pk/pakistan/wp-content/uploads/2019/06/Sheosar-Lake-1024x768.jpg", "thumbnail": "https://serpapi.com/searches/679f57ec8ba25768fc7fa679/images/1a6da710ac2a27c512317574c8264b7c6b0c7a4c1d9e97f8a60880f093b7774f.jpeg", "title": "Deosai National Park - GB - Pakistan ...", "source": "GetOut Adventure", "width": 1024, "height": 768}, {"original": "http://www.pakistantravelguide.pk/wp-content/uploads/2016/02/Deosai-pakistan.png", "thumbnail": "https://serpapi.com/searches/679f57ec8ba25768fc7fa679/images/1a6da710ac2a27c5229ab151507142754bf9fffa78c16fcc4de4f0c8a8c73780.jpeg", "title": "The Land of Giants", "source": "Pakistan Travel Guide", "width": 875, "height": 607}, {"original": "https://upload.wikimedia.org/wikipedia/commons/d/de/Deosai_Plateau_2.jpg", "thumbnail": "https://serpapi.com/searches/679f57ec8ba25768fc7fa679/images/1a6da710ac2a27c50bbe2cdd3a63bbf299deea2446f453d35dc91449c7ed57cf.jpeg", "title": "Deosai National Park – Travel guide at ...", "source": "Wikivoyage", "width": 1024, "height": 768}]
# ================================= Tool Message =================================
# Name: image_finder
#
# [{"original": "https://upload.wikimedia.org/wikipedia/commons/1/13/Shigar_Fort_by_ZILL_NIAZI_22.jpg", "thumbnail": "https://serpapi.com/searches/679f57ecb705d69d90d703fb/images/846fe11c59786ecf07e4f6a3d4eafc3c90f4e3f2fc82dbd2d9bcae9d5ef32844.jpeg", "title": "Shigar Fort - Wikipedia", "source": "Wikipedia", "width": 6016, "height": 4016}, {"original": "https://image-tc.galaxy.tf/wijpeg-dpekkkio9e54dgpqijbr67u8/exterior5.jpg?width=1600&height=1066", "thumbnail": "https://serpapi.com/searches/679f57ecb705d69d90d703fb/images/846fe11c59786ecf94c182bccb433d74fa8adf054d04b087ffb6e026a6c42156.jpeg", "title": "Serena Shigar Fort | Pakistan Heritage ...", "source": "Serena Hotels", "width": 1600, "height": 1063}, {"original": "https://image-tc.galaxy.tf/wijpeg-b4resfo5n87xqnbr1yw9dil7e/standard2.jpg?width=767", "thumbnail": "https://serpapi.com/searches/679f57ecb705d69d90d703fb/images/846fe11c59786ecf7972cba991192dbd105ceaba47af624701d32b2a1e355674.jpeg", "title": "Serena Shigar Fort | Pakistan Heritage ...", "source": "Serena Hotels", "width": 767, "height": 510}, {"original": "https://static.the.akdn/53832/1641715114-shigar_fort-56759_0.jpg", "thumbnail": "https://serpapi.com/searches/679f57ecb705d69d90d703fb/images/846fe11c59786ecf116e7bf4cca0e920541247f487260a7bc12f755c3e30fe46.jpeg", "title": "Shigar Fort: a new model of ...", "source": "AKDN", "width": 1200, "height": 800}, {"original": "https://pyaraskardu.com/wp-content/uploads/2023/02/shigar-960x576.jpg", "thumbnail": "https://serpapi.com/searches/679f57ecb705d69d90d703fb/images/846fe11c59786ecf2dcd6f0891ed2dfdb364861df0b88a8e2422e30849c11607.jpeg", "title": "Shigar Fort Skardu - PYARA SKARDU", "source": "pyara skardu", "width": 960, "height": 576}, {"original": "https://q-xx.bstatic.com/xdata/images/hotel/max1024x768/183084859.jpg?k=e86fcde07a4756c21b8c58f1a200818312fdbf5927fdebc96d36fe696ceeb4ec&o=", "thumbnail": "https://serpapi.com/searches/679f57ecb705d69d90d703fb/images/846fe11c59786ecf4fc160baf8a8ba8e57166359b114be9f18e6b63f561ff2de.jpeg", "title": "Serena Shigar Fort - 2025 Exclusive Deals", "source": "Agoda.com", "width": 1024, "height": 683}, {"original": "https://i.dawn.com/primary/2018/05/5af4244f6459f.jpg", "thumbnail": "https://serpapi.com/searches/679f57ecb705d69d90d703fb/images/846fe11c59786ecf2d50e43af06d0ea51bf1d4832d9a0433579a68eca3ec09eb.jpeg", "title": "Gilgit-Baltistan ...", "source": "Dawn", "width": 1500, "height": 900}, {"original": "https://image-tc.galaxy.tf/wijpeg-3gt6qxxtr44wl6zfevhnpyt0g/exterior3.jpg?width=1600&height=1066", "thumbnail": "https://serpapi.com/searches/679f57ecb705d69d90d703fb/images/846fe11c59786ecfeee3935125362b9c6e26a16c3bab836101f1f4fc378cc64a.jpeg", "title": "Serena Shigar Fort | Pakistan Heritage ...", "source": "Serena Hotels", "width": 1600, "height": 1063}, {"original": "https://q-xx.bstatic.com/xdata/images/hotel/max500/183085100.jpg?k=ec22321c38e1aec15003aec2d1ca633f7a1abd59773ee9a74b211850682f9d95&o=", "thumbnail": "https://serpapi.com/searches/679f57ecb705d69d90d703fb/images/846fe11c59786ecfb4888c2bdd3afb94b46b2151f071b9981284b71b37769308.jpeg", "title": "Serena Shigar Fort - 2025 Exclusive Deals", "source": "Agoda.com", "width": 334, "height": 500}, {"original": "https://cf.bstatic.com/xdata/images/hotel/max1024x768/183085116.jpg?k=1154738aba64278c748221bb89dce40591dc118766fe23c0d64602ec702d6c88&o=&hp=1", "thumbnail": "https://serpapi.com/searches/679f57ecb705d69d90d703fb/images/846fe11c59786ecfb7ab711c93ca56d02a8b0fb22c1add178995370cf41a4c0c.jpeg", "title": "Serena Shigar Fort, Shigar (updated ...", "source": "Booking.com", "width": 1024, "height": 683}]
# ================================= Tool Message =================================
# Name: image_finder
#
# [{"original": "https://goskardu.com/uploads/1677843398.jpg", "thumbnail": "https://serpapi.com/searches/679f57ec3dca69fd3f521fd6/images/a2dfa072dd25d920c1a3a22307a95f6fc809aebfca275c66bc956796c11e3acc.jpeg", "title": "GoSkardu - The Festivals of Skardu ...", "source": "GoSkardu - Discover Skardu", "width": 860, "height": 573}, {"original": "https://lookaside.fbsbx.com/lookaside/crawler/media/?media_id=2298039326879747", "thumbnail": "https://serpapi.com/searches/679f57ec3dca69fd3f521fd6/images/a2dfa072dd25d92093575cb6ec2c3aee49815fc8cc640319db91b95be44437f8.jpeg", "title": "Express Tribune - Gilgit Baltistan ...", "source": "Facebook", "width": 1080, "height": 801}, {"original": "https://www.ajktours.com/wp-content/uploads/2023/11/ismali-1024x720.jpg.webp", "thumbnail": "https://serpapi.com/searches/679f57ec3dca69fd3f521fd6/images/a2dfa072dd25d9202dc487a3a493707f072b4b723f289fdc60e0de4fc8086b4f.jpeg", "title": "Unveiling the Rich Culture of Skardu ...", "source": "AJK Tours", "width": 1024, "height": 720}, {"original": "https://www.ajktours.com/wp-content/uploads/2024/02/deosai-800x600-800x600-2.webp", "thumbnail": "https://serpapi.com/searches/679f57ec3dca69fd3f521fd6/images/a2dfa072dd25d920357e40e931895e800946991fd05beebbcf66be64c51feb25.jpeg", "title": "Why Skardu Is More Beautiful Then Hunza ...", "source": "AJK Tours", "width": 800, "height": 600}, {"original": "https://www.ajktours.com/wp-content/uploads/2023/12/Silk-Route-Festival-1.jpg", "thumbnail": "https://serpapi.com/searches/679f57ec3dca69fd3f521fd6/images/a2dfa072dd25d920b124e0053665189d4702bdc08110ed7874c263087d9b1067.jpeg", "title": "Skardu Valley with Ajk Tours ...", "source": "AJK Tours", "width": 700, "height": 434}, {"original": "https://lookaside.instagram.com/seo/google_widget/crawler/?media_id=2699614251214957792", "thumbnail": "https://serpapi.com/searches/679f57ec3dca69fd3f521fd6/images/a2dfa072dd25d9204b5afebd41b1eeaee0fd1bedeaae199e09a300b91ff807f0.jpeg", "title": "Beautiful Baltistan cultural Dress ...", "source": "Instagram", "width": 720, "height": 865}, {"original": "https://thekarakoram.com.pk/wp-content/uploads/2023/01/abjanbalti_1640293734150_2.jpg", "thumbnail": "https://serpapi.com/searches/679f57ec3dca69fd3f521fd6/images/a2dfa072dd25d92060ce4d6cb914303a7970e3827b96d4408369feb32e727b21.jpeg", "title": "Jashn-e-Mefung - The Karakoram", "source": "The Karakoram", "width": 720, "height": 720}, {"original": "https://media.licdn.com/dms/image/v2/D4D12AQFz9etUfYyB9Q/article-cover_image-shrink_720_1280/article-cover_image-shrink_720_1280/0/1678699030322?e=2147483647&v=beta&t=FTTRaFRGvi5B68OyfqH4r7DlJGhNrSTsBucffPHzPX8", "thumbnail": "https://serpapi.com/searches/679f57ec3dca69fd3f521fd6/images/a2dfa072dd25d92023857a17d1573bd01b8cb90299578837a9019866573e7b32.jpeg", "title": "Skardu: Exploring the Natural, Cultural ...", "source": "LinkedIn", "width": 1280, "height": 720}, {"original": "https://i.tribune.com.pk/media/images/21602864188-2/21602864188-2.jpg", "thumbnail": "https://serpapi.com/searches/679f57ec3dca69fd3f521fd6/images/a2dfa072dd25d9200c20e49982b5e7c49520348396b76e26a5045d22a1418f5b.jpeg", "title": "Urwa Hocane Explores Skardu", "source": "The Express Tribune", "width": 900, "height": 659}, {"original": "https://oric.superior.edu.pk/wp-content/uploads/2023/05/Sakrdu-article-picture.webp", "thumbnail": "https://serpapi.com/searches/679f57ec3dca69fd3f521fd6/images/a2dfa072dd25d920cfc9081a850c03678841f9546bd4bf36eef0cae010c642c2.jpeg", "title": "Khaplu, Shigar, and Kharpocho Forts ...", "source": "ORIC - Superior University", "width": 1000, "height": 600}]
# ================================== Ai Message ==================================
#
# Here's a detailed itinerary for your trip to Skardu, Pakistan, tailored to your interests in sightseeing and local cuisine, within a budget of $5000 for 2 people over 7 days.
#
# ```json
# {
#   "trip_details": {
#     "destination": "Skardu",
#     "duration": 7,
#     "travel_date": "2025-10-03",
#     "companions": 2,
#     "budget": 5000.0,
#     "interests": ["sightseeing", "local cuisine"]
#   },
#   "daily_itinerary": [
#     {
#       "day": 1,
#       "date": "2025-10-03",
#       "day_title": "Arrival Day",
#       "description": "Arrive in Skardu and settle into the hotel. Explore local markets and enjoy your first dinner in Skardu.",
#       "hotel": {
#         "name": "The Que Skardu",
#         "price": 150,
#         "rating": 5,
#         "reviews": 275,
#         "image_url": "https://lh5.googleusercontent.com/p/AF1QipMel55XpUZvKEOfY3PViwlBRY9DSQFDSuMlgt9Z=s10000",
#         "booking_url": "https://serpapi.com/search.json?adults=2&check_in_date=2025-10-03&check_out_date=2025-10-10&children=0&currency=PKR&engine=google_hotels&gl=pk&hl=en&property_token=ChoIz4y-o_uSy5SGARoNL2cvMTFscDd5aGh4NxAB&q=Skardu&sort_by=8"
#       },
#       "transportation": {
#         "type": "Taxi",
#         "cost": 70
#       },
#       "meals": [
#         {
#           "type": "Dinner",
#           "venue": "Food Corridor",
#           "cost": 25,
#           "image_url": "https://lh5.googleusercontent.com/p/AF1QipPFEUSe0AnnRvvrRzs2hogm-TxUet2MQDrgaZKD=s287-w287-h192-n-k-no-v1"
#         }
#       ],
#       "activities": [],
#       "daily_cost_breakdown": {
#         "hotel": 150,
#         "transportation": 70,
#         "food": 25,
#         "activities": 0,
#         "total": 245
#       }
#     },
#     {
#       "day": 2,
#       "date": "2025-10-04",
#       "day_title": "Sightseeing Day",
#       "description": "Visit Upper Kachura Lake and enjoy kayaking. Dinner at a local restaurant.",
#       "hotel": {
#         "name": "The Que Skardu",
#         "price": 150,
#         "rating": 5,
#         "reviews": 275,
#         "image_url": "https://lh5.googleusercontent.com/p/AF1QipMel55XpUZvKEOfY3PViwlBRY9DSQFDSuMlgt9Z=s10000",
#         "booking_url": "https://serpapi.com/search.json?adults=2&check_in_date=2025-10-03&check_out_date=2025-10-10&children=0&currency=PKR&engine=google_hotels&gl=pk&hl=en&property_token=ChoIz4y-o_uSy5SGARoNL2cvMTFscDd5aGh4NxAB&q=Skardu&sort_by=8"
#       },
#       "transportation": {
#         "type": "Taxi",
#         "cost": 40
#       },
#       "meals": [
#         {
#           "type": "Breakfast",
#           "venue": "Hotel",
#           "cost": 15,
#           "image_url": "https://lh5.googleusercontent.com/p/AF1QipPFEUSe0AnnRvvrRzs2hogm-TxUet2MQDrgaZKD=s287-w287-h192-n-k-no-v1"
#         },
#         {
#           "type": "Lunch",
#           "venue": "Upper Kachura Lake Restaurant",
#           "cost": 30,
#           "image_url": "https://lh5.googleusercontent.com/p/AF1QipOue8bnL4eO2p_Vmt8LDxL_9vuCEp4NIU-Zna9x=s287-w287-h192-n-k-no-v1"
#         },
#         {
#           "type": "Dinner",
#           "venue": "Food Corridor",
#           "cost": 25,
#           "image_url": "https://lh5.googleusercontent.com/p/AF1QipN6DznDc4d857mSifP98lk01zLr4Mh8f5G2iLwT=s287-w287-h192-n-k-no-v1"
#         }
#       ],
#       "activities": [
#         {
#           "name": "Kayaking at Upper Kachura Lake",
#           "description": "Enjoy kayaking on the stunning Upper Kachura Lake.",
#           "cost": 50,
#           "image_url": "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/0d/39/26/f2/upper-kachura-lake-is.jpg?w=1200&h=700&s=1",
#           "location_images": [
#             {
#               "url": "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/0d/39/26/f2/upper-kachura-lake-is.jpg?w=1200&h=700&s=1",
#               "title": "Upper Kachura Lake",
#               "source": "Tripadvisor"
#             }
#           ]
#         }
#       ],
#       "daily_cost_breakdown": {
#         "hotel": 150,
#         "transportation": 40,
#         "food": 70,
#         "activities": 50,
#         "total": 310
#       }
#     },
#     {
#       "day": 3,
#       "date": "2025-10-05",
#       "day_title": "Adventure Day",
#       "description": "Visit Deosai National Park for its stunning views and diverse wildlife.",
#       "hotel": {
#         "name": "The Que Skardu",
#         "price": 150,
#         "rating": 5,
#         "reviews": 275,
#         "image_url": "https://lh5.googleusercontent.com/p/AF1QipMel55XpUZvKEOfY3PViwlBRY9DSQFDSuMlgt9Z=s10000",
#         "booking_url": "https://serpapi.com/search.json?adults=2&check_in_date=2025-10-03&check_out_date=2025-10-10&children=0&currency=PKR&engine=google_hotels&gl=pk&hl=en&property_token=ChoIz4y-o_uSy5SGARoNL2cvMTFscDd5aGh4NxAB&q=Skardu&sort_by=8"
#       },
#       "transportation": {
#         "type": "4WD Rental",
#         "cost": 120
#       },
#       "meals": [
#         {
#           "type": "Breakfast",
#           "venue": "Hotel",
#           "cost": 15,
#           "image_url": "https://lh5.googleusercontent.com/p/AF1QipPFEUSe0AnnRvvrRzs2hogm-TxUet2MQDrgaZKD=s287-w287-h192-n-k-no-v1"
#         },
#         {
#           "type": "Lunch",
#           "venue": "Deosai Picnic Lunch",
#           "cost": 30,
#           "image_url": "https://lh5.googleusercontent.com/p/AF1QipN6DznDc4d857mSifP98lk01zLr4Mh8f5G2iLwT=s287-w287-h192-n-k-no-v1"
#         },
#         {
#           "type": "Dinner",
#           "venue": "Local Diner",
#           "cost": 30,
#           "image_url": "https://lh5.googleusercontent.com/p/AF1QipN6DznDc4d857mSifP98lk01zLr4Mh8f5G2iLwT=s287-w287-h192-n-k-no-v1"
#         }
#       ],
#       "activities": [
#         {
#           "name": "Deosai National Park Visit",
#           "description": "Experience the vast plains and wildlife of Deosai National Park.",
#           "cost": 70,
#           "image_url": "https://upload.wikimedia.org/wikipedia/commons/7/7b/Deosai_pic_hd.jpg",
#           "location_images": [
#             {
#               "url": "https://upload.wikimedia.org/wikipedia/commons/7/7b/Deosai_pic_hd.jpg",
#               "title": "Deosai National Park",
#               "source": "Wikipedia"
#             }
#           ]
#         }
#       ],
#       "daily_cost_breakdown": {
#         "hotel": 150,
#         "transportation": 120,
#         "food": 75,
#         "activities": 70,
#         "total": 415
#       }
#     },
#     {
#       "day": 4,
#       "date": "2025-10-06",
#       "day_title": "Cultural Exploration",
#       "description": "Visit Shigar Fort and learn about the local history and culture, followed by a visit to the local markets.",
#       "hotel": {
#         "name": "The Que Skardu",
#         "price": 150,
#         "rating": 5,
#         "reviews": 275,
#         "image_url": "https://lh5.googleusercontent.com/p/AF1QipMel55XpUZvKEOfY3PViwlBRY9DSQFDSuMlgt9Z=s10000",
#         "booking_url": "https://serpapi.com/search.json?adults=2&check_in_date=2025-10-03&check_out_date=2025-10-10&children=0&currency=PKR&engine=google_hotels&gl=pk&hl=en&property_token=ChoIz4y-o_uSy5SGARoNL2cvMTFscDd5aGh4NxAB&q=Skardu&sort_by=8"
#       },
#       "transportation": {
#         "type": "Taxi",
#         "cost": 50
#       },
#       "meals": [
#         {
#           "type": "Breakfast",
#           "venue": "Hotel",
#           "cost": 15,
#           "image_url": "https://lh5.googleusercontent.com/p/AF1QipPFEUSe0AnnRvvrRzs2hogm-TxUet2MQDrgaZKD=s287-w287-h192-n-k-no-v1"
#         },
#         {
#           "type": "Lunch",
#           "venue": "Local Restaurant",
#           "cost": 20,
#           "image_url": "https://lh5.googleusercontent.com/p/AF1QipN6DznDc4d857mSifP98lk01zLr4Mh8f5G2iLwT=s287-w287-h192-n-k-no-v1"
#         },
#         {
#           "type": "Dinner",
#           "venue": "Restaurant at Shigar Fort",
#           "cost": 30,
#           "image_url": "https://lh5.googleusercontent.com/p/AF1QipN6DznDc4d857mSifP98lk01zLr4Mh8f5G2iLwT=s287-w287-h192-n-k-no-v1"
#         }
#       ],
#       "activities": [
#         {
#           "name": "Visit Shigar Fort",
#           "description": "Explore the historic Shigar Fort and its museum.",
#           "cost": 10,
#           "image_url": "https://upload.wikimedia.org/wikipedia/commons/1/13/Shigar_Fort_by_ZILL_NIAZI_22.jpg",
#           "location_images": [
#             {
#               "url": "https://upload.wikimedia.org/wikipedia/commons/1/13/Shigar_Fort_by_ZILL_NIAZI_22.jpg",
#               "title": "Shigar Fort",
#               "source": "Wikipedia"
#             }
#           ]
#         }
#       ],
#       "daily_cost_breakdown": {
#         "hotel": 150,
#         "transportation": 50,
#         "food": 65,
#         "activities": 10,
#         "total": 275
#       }
#     },
#     {
#       "day": 5,
#       "date": "2025-10-07",
#       "day_title": "Relaxation and Shopping",
#       "description": "Leisure day for shopping and relaxing at local cafes.",
#       "hotel": {
#         "name": "The Que Skardu",
#         "price": 150,
#         "rating": 5,
#         "reviews": 275,
#         "image_url": "https://lh5.googleusercontent.com/p/AF1QipMel55XpUZvKEOfY3PViwlBRY9DSQFDSuMlgt9Z=s10000",
#         "booking_url": "https://serpapi.com/search.json?adults=2&check_in_date=2025-10-03&check_out_date=2025-10-10&children=0&currency=PKR&engine=google_hotels&gl=pk&hl=en&property_token=ChoIz4y-o_uSy5SGARoNL2cvMTFscDd5aGh4NxAB&q=Skardu&sort_by=8"
#       },
#       "transportation": {
#         "type": "Walking",
#         "cost": 0
#       },
#       "meals": [
#         {
#           "type": "Breakfast",
#           "venue": "Hotel",
#           "cost": 15,
#           "image_url": "https://lh5.googleusercontent.com/p/AF1QipPFEUSe0AnnRvvrRzs2hogm-TxUet2MQDrgaZKD=s287-w287-h192-n-k-no-v1"
#         },
#         {
#           "type": "Lunch",
#           "venue": "Café",
#           "cost": 20,
#           "image_url": "https://lh5.googleusercontent.com/p/AF1QipN6DznDc4d857mSifP98lk01zLr4Mh8f5G2iLwT=s287-w287-h192-n-k-no-v1"
#         },
#         {
#           "type": "Dinner",
#           "venue": "Local Restaurant",
#           "cost": 30,
#           "image_url": "https://lh5.googleusercontent.com/p/AF1QipN6DznDc4d857mSifP98lk01zLr4Mh8f5G2iLwT=s287-w287-h192-n-k-no-v1"
#         }
#       ],
#       "activities": [],
#       "daily_cost_breakdown": {
#         "hotel": 150,
#         "transportation": 0,
#         "food": 65,
#         "activities": 0,
#         "total": 215
#       }
#     },
#     {
#       "day": 6,
#       "date": "2025-10-08",
#       "day_title": "Nature Day",
#       "description": "Visit Lower Kachura Lake for pristine views and relaxation.",
#       "hotel": {
#         "name": "The Que Skardu",
#         "price": 150,
#         "rating": 5,
#         "reviews": 275,
#         "image_url": "https://lh5.googleusercontent.com/p/AF1QipMel55XpUZvKEOfY3PViwlBRY9DSQFDSuMlgt9Z=s10000",
#         "booking_url": "https://serpapi.com/search.json?adults=2&check_in_date=2025-10-03&check_out_date=2025-10-10&children=0&currency=PKR&engine=google_hotels&gl=pk&hl=en&property_token=ChoIz4y-o_uSy5SGARoNL2cvMTFscDd5aGh4NxAB&q=Skardu&sort_by=8"
#       },
#       "transportation": {
#         "type": "Taxi",
#         "cost": 50
#       },
#       "meals": [
#         {
#           "type": "Breakfast",
#           "venue": "Hotel",
#           "cost": 15,
#           "image_url": "https://lh5.googleusercontent.com/p/AF1QipPFEUSe0AnnRvvrRzs2hogm-TxUet2MQDrgaZKD=s287-w287-h192-n-k-no-v1"
#         },
#         {
#           "type": "Lunch",
#           "venue": "Picnic Lunch",
#           "cost": 20,
#           "image_url": "https://lh5.googleusercontent.com/p/AF1QipN6DznDc4d857mSifP98lk01zLr4Mh8f5G2iLwT=s287-w287-h192-n-k-no-v1"
#         },
#         {
#           "type": "Dinner",
#           "venue": "Local Restaurant",
#           "cost": 30,
#           "image_url": "https://lh5.googleusercontent.com/p/AF1QipN6DznDc4d857mSifP98lk01zLr4Mh8f5G2iLwT=s287-w287-h192-n-k-no-v1"
#         }
#       ],
#       "activities": [
#         {
#           "name": "Relax at Lower Kachura Lake",
#           "description": "Enjoy the beautiful scenery and relax by the lake.",
#           "cost": 20,
#           "image_url": "https://upload.wikimedia.org/wikipedia/commons/5/5b/Shangrila%2C_Lower_Kachura_Lake.jpg",
#           "location_images": [
#             {
#               "url": "https://upload.wikimedia.org/wikipedia/commons/5/5b/Shangrila%2C_Lower_Kachura_Lake.jpg",
#               "title": "Lower Kachura Lake",
#               "source": "Wikipedia"
#             }
#           ]
#         }
#       ],
#       "daily_cost_breakdown": {
#         "hotel": 150,
#         "transportation": 50,
#         "food": 65,
#         "activities": 20,
#         "total": 285
#       }
#     },
#     {
#       "day": 7,
#       "date": "2025-10-09",
#       "day_title": "Departure Day",
#       "description": "Check out and head to the airport for departure.",
#       "hotel": {
#         "name": "The Que Skardu",
#         "price": 150,
#         "rating": 5,
#         "reviews": 275,
#         "image_url": "https://lh5.googleusercontent.com/p/AF1QipMel55XpUZvKEOfY3PViwlBRY9DSQFDSuMlgt9Z=s10000",
#         "booking_url": "https://serpapi.com/search.json?adults=2&check_in_date=2025-10-03&check_out_date=2025-10-10&children=0&currency=PKR&engine=google_hotels&gl=pk&hl=en&property_token=ChoIz4y-o_uSy5SGARoNL2cvMTFscDd5aGh4NxAB&q=Skardu&sort_by=8"
#       },
#       "transportation": {
#         "type": "Taxi",
#         "cost": 70
#       },
#       "meals": [
#         {
#           "type": "Breakfast",
#           "venue": "Hotel",
#           "cost": 15,
#           "image_url": "https://lh5.googleusercontent.com/p/AF1QipPFEUSe0AnnRvvrRzs2hogm-TxUet2MQDrgaZKD=s287-w287-h192-n-k-no-v1"
#         }
#       ],
#       "activities": [],
#       "daily_cost_breakdown": {
#         "hotel": 0,
#         "transportation": 70,
#         "food": 15,
#         "activities": 0,
#         "total": 85
#       }
#     }
#   ],
#   "cost_summary": {
#     "daily_totals": [
#       {
#         "day": 1,
#         "amount": 245
#       },
#       {
#         "day": 2,
#         "amount": 310
#       },
#       {
#         "day": 3,
#         "amount": 415
#       },
#       {
#         "day": 4,
#         "amount": 275
#       },
#       {
#         "day": 5,
#         "amount": 215
#       },
#       {
#         "day": 6,
#         "amount": 285
#       },
#       {
#         "day": 7,
#         "amount": 85
#       }
#     ],
#     "total_cost": 1515,
#     "remaining_budget": 3485
#   }
# }
# ```
#
# ### Key Highlights:
# - **Cultural Activities**: Visits to significant historical sites like Shigar Fort and local cooking experiences to indulge in the cuisine.
# - **Relaxing Days**: Plenty of time at scenic locations like Kachura Lakes.
# - **Local Cuisine**: Meals at highly rated local restaurants and cafes.
# - **Flexibility**: The itinerary allows for exploration and adventure while being mindful of the budget.

# %%
print("\n[FINAL RESPONSE]\n",messages)
# Out:
# [FINAL RESPONSE]
#  {'messages': [HumanMessage(content='Plan my trip to Pakistan', additional_kwargs={}, response_metadata={}, id='ae2cce99-88d3-4f20-bbd0-a8096d365e30'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_V1XnBdTXIp5rxifurzGLKKhr', 'function': {'arguments': '{"params": {"q": "Skardu", "check_in_date": "2025-10-03", "check_out_date": "2025-10-10", "adults": 2}}', 'name': 'hotels_finder'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 64, 'prompt_tokens': 366, 'total_tokens': 430, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_72ed7ab54c', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-5a0f212a-c209-4a53-b265-66c16c952a77-0', tool_calls=[{'name': 'hotels_finder', 'args': {'params': {'q': 'Skardu', 'check_in_date': '2025-10-03', 'check_out_date': '2025-10-10', 'adults': 2}}, 'id': 'call_V1XnBdTXIp5rxifurzGLKKhr', 'type': 'tool_call'}], usage_metadata={'input_tokens': 366, 'output_tokens': 64, 'total_tokens': 430, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='[{"type": "hotel", "name": "The Que Skardu", "gps_coordinates": {"latitude": 35.4430589, "longitude": 75.45204890000001}, "nearby_places": [{"name": "Upper Kachura Lake", "transportations": [{"type": "Walking", "duration": "1 min"}]}, {"name": "Islamabad International Airport", "transportations": [{"type": "Taxi", "duration": "14 hr 1 min"}]}, {"name": "Ali Zada Hotel and Restaurant Upper kachurara", "transportations": [{"type": "Walking", "duration": "1 min"}]}], "images": [{"thumbnail": "https://lh5.googleusercontent.com/p/AF1QipMel55XpUZvKEOfY3PViwlBRY9DSQFDSuMlgt9Z=s287-w287-h192-n-k-no-v1", "original_image": "https://lh5.googleusercontent.com/p/AF1QipMel55XpUZvKEOfY3PViwlBRY9DSQFDSuMlgt9Z=s10000"}, {"thumbnail": "https://lh5.googleusercontent.com/p/AF1QipPiJeagtgthR_AH48tkZHAvaliAhZbjjwRthMoH=s287-w287-h192-n-k-no-v1", "original_image": "https://lh5.googleusercontent.com/p/AF1QipPiJeagtgthR_AH48tkZHAvaliAhZbjjwRthMoH=s10000"}, {"thumbnail": "https://lh5.googleusercontent.com/p/AF1QipP1Ct0dFF74cjtsSOKtl45SGGzF8pWrHByTX7Oi=s287-w287-h192-n-k-no-v1", "original_image": "https://lh5.googleusercontent.com/p/AF1QipP1Ct0dFF74cjtsSOKtl45SGGzF8pWrHByTX7Oi=s10000"}, {"thumbnail": "https://lh5.googleusercontent.com/p/AF1QipMd38_qXmf9yhiHzLQlj7s3_KrUE01d5UBTuJ9t=s287-w287-h192-n-k-no-v1", "original_image": "https://lh5.googleusercontent.com/p/AF1QipMd38_qXmf9yhiHzLQlj7s3_KrUE01d5UBTuJ9t=s10000"}, {"thumbnail": "https://lh5.googleusercontent.com/p/AF1QipPMyRyRDrQ669iKyAzWzvzPNgILu6BfUyAb_5qf=s287-w287-h192-n-k-no-v1", "original_image": "https://lh5.googleusercontent.com/p/AF1QipPMyRyRDrQ669iKyAzWzvzPNgILu6BfUyAb_5qf=s10000"}, {"thumbnail": "https://lh5.googleusercontent.com/p/AF1QipOue8bnL4eO2p_Vmt8LDxL_9vuCEp4NIU-Zna9x=s287-w287-h192-n-k-no-v1", "original_image": "https://lh5.googleusercontent.com/p/AF1QipOue8bnL4eO2p_Vmt8LDxL_9vuCEp4NIU-Zna9x=s10000"}, {"thumbnail": "https://lh5.googleusercontent.com/p/AF1QipMTUrhdQveQGsDmzUdwBcL6WoE4rn1QOwaH1kDM=s287-w287-h192-n-k-no-v1", "original_image": "https://lh5.googleusercontent.com/p/AF1QipMTUrhdQveQGsDmzUdwBcL6WoE4rn1QOwaH1kDM=s10000"}, {"thumbnail": "https://lh5.googleusercontent.com/p/AF1QipM9kIAD8-kV6SRhQ20z_sh71zf7VvXnhHcKKC1h=s287-w287-h192-n-k-no-v1", "original_image": "https://lh5.googleusercontent.com/p/AF1QipM9kIAD8-kV6SRhQ20z_sh71zf7VvXnhHcKKC1h=s10000"}, {"thumbnail": "https://lh5.googleusercontent.com/p/AF1QipMf26QdNjxGhecq-eF9l7QaD3z6Z2df4-KDOa75=s287-w287-h192-n-k-no-v1", "original_image": "https://lh5.googleusercontent.com/p/AF1QipMf26QdNjxGhecq-eF9l7QaD3z6Z2df4-KDOa75=s10000"}], "overall_rating": 5, "reviews": 265, "ratings": [{"stars": 5, "co ...

# %%
# from langchain_core.messages import AIMessage, HumanMessage, SystemMessage,ToolMessage
# from langgraph.prebuilt import tools_condition, ToolNode
# from langgraph.graph import StateGraph, END ,START
# from IPython.display import display, Image
# from langgraph.checkpoint.memory import MemorySaver
# from langgraph.graph.state import CompiledStateGraph
# from langgraph.graph import MessagesState

# def assistant(state: MessagesState)->MessagesState:
#     # system_prompt = SystemMessage(content=get_system_prompt(state))
#     # messages = [system_prompt] + state['messages']
#     messages = state['messages']
#     response = llm_with_tools.invoke(messages)
#     # response = llm.invoke(messages)
#     return {"messages": [response]}

# # # New itinerary creation node
# # def create_itinerary(state: AgentState):
# #     # Parse tool responses and format itinerary
# #     itinerary = []
# #     tool_results = [msg.content for msg in state['messages'] if isinstance(msg, ToolMessage)]

# #     # Create structured itinerary (simplified example)
# #     itinerary_entry = {
# #         "city": state['city'],
# #         "days": state['days'],
# #         "daily_plan": [],
# #         "total_estimated_cost": state['budget']
# #     }

# #     # Add parsed tool data to itinerary
# #     for result in tool_results:
# #         if 'hotels' in result:
# #             itinerary_entry['hotels'] = result['hotels'][:3]  # Top 3 hotels

# #     return {"itinerary": [itinerary_entry], "messages": [AIMessage(content="Itinerary created!")]}

# # Modified graph construction
# builder = StateGraph(MessagesState)
# builder.add_node("assistant", assistant)
# builder.add_node("tools", ToolNode([tools]))  # Add other tools as needed
# # builder.add_node("create_itinerary", create_itinerary)

# # Edge connections
# builder.add_edge(START, "assistant")
# builder.add_conditional_edges(
#     "assistant",
#     # If the latest message (result) from assistant is a tool call -> tools_condition routes to tools
#     # If the latest message (result) from assistant is a not a tool call -> tools_condition routes to END
#     tools_condition,
# )
# # builder.add_conditional_edges(
# #     "assistant",
# #     tools_condition,
# #     {
# #         "call_tools": "tools",
# #         "continue": "create_itinerary"
# #     }
# # )
# builder.add_edge("tools", "assistant")




# memory: MemorySaver = MemorySaver()
# graph: CompiledStateGraph = builder.compile( checkpointer=memory)

# # Show
# display(Image(graph.get_graph(xray=True).draw_mermaid_png()))

# %%
messages = graph.invoke({"messages": messages},config1)
for m in messages['messages']:
    m.pretty_print()

# %%
result = graph.invoke(
    initial_state,
    config1
)
# Out:
# ERROR:grpc._plugin_wrapping:AuthMetadataPluginCallback "<google.auth.transport.grpc.AuthMetadataPlugin object at 0x79cc890d4e10>" raised exception!
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/compute_engine/credentials.py", line 128, in refresh
#     self._retrieve_info(request)
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/compute_engine/credentials.py", line 101, in _retrieve_info
#     info = _metadata.get_service_account_info(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/compute_engine/_metadata.py", line 323, in get_service_account_info
#     return get(request, path, params={"recursive": "true"})
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/compute_engine/_metadata.py", line 248, in get
#     raise exceptions.TransportError(
# google.auth.exceptions.TransportError: ("Failed to retrieve http://metadata.google.internal/computeMetadata/v1/instance/service-accounts/default/?recursive=true from the Google Compute Engine metadata service. Status: 404 Response:\nb''", <google.auth.transport.requests._Response object at 0x79ccc5cba890>)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/grpc/_plugin_wrapping.py", line 105, in __call__
#     self._metadata_plugin(
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/transport/grpc.py", line 95, in __call__
#     callback(self._get_authorization_headers(context), None)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/transport/grpc.py", line 81, in _get_authorization_headers
#     self._credentials.before_request(
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/credentials.py", line 228, in before_request
#     self._blocking_refresh(request)
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/credentials.py", line 191, in _blocking_refresh
#     self.refresh(request)
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/compute_engine/credentials.py", line 134, in refresh
#     raise new_exc from caught_exc
# google.auth.exceptions.RefreshError: ("Failed to retrieve http://metadata.google.internal/computeMetadata/v1/instance/service-accounts/default/?recursive=true from the Google Compute Engine metadata service. Status: 404 Response:\nb''", <google.auth.transport.requests._Response object at 0x79ccc5cba890>)
# WARNING:langsmith.client:Failed to send compressed multipart ingest: langsmith.utils.LangSmithAuthError: Authentication failed for https://api.smith.langchain.com/runs/multipart. HTTPError('401 Client Error: Unauthorized for url: https://api.smith.langchain.com/runs/multipart', '{"detail":"Invalid token"}')
# ERROR:grpc._plugin_wrapping:AuthMetadataPluginCallback "<google.auth.transport.grpc.AuthMetadataPlugin object at 0x79cc890d4e10>" raised exception!
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/compute_engine/credentials.py", line 128, in refresh
#     self._retrieve_info(request)
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/compute_engine/credentials.py", line 101, in _retrieve_info
#     info = _metadata.get_service_account_info(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/compute_engine/_metadata.py", line 323, in get_service_account_info
#     return get(request, path, params={"recursive": "true"})
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/compute_engine/_metadata.py", line 248, in get
#     raise exceptions.TransportError(
# google.auth.exceptions.TransportError: ("Failed to retrieve http://metadata.google.internal/computeMetadata/v1/instance/service-accounts/default/?recursive=true from the Google Compute Engine metadata service. Status: 404 Response:\nb''", <google.auth.transport.requests._Response object at 0x79cc8917fc90>)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/grpc/_plugin_wrapping.py", line 105, in __call__
#     self._metadata_plugin(
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/transport/grpc.py", line 95, in __call__
#     callback(self._get_authorization_headers(context), None)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/transport/grpc.py", line 81, in _get_authorization_headers
#     self._credentials.before_request(
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/credentials.py", line 228, in before_request
#     self._blocking_refresh(request)
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/credentials.py", line 191, in _blocking_refresh
#     self.refresh(request)
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/compute_engine/credentials.py", line 134, in refresh
#     raise new_exc from caught_exc
# google.auth.exceptions.RefreshError: ("Failed to retrieve http://metadata.google.internal/computeMetadata/v1/instance/service-accounts/default/?recursive=true from the Google Compute Engine metadata service. Status: 404 Response:\nb''", <google.auth.transport.requests._Response object at 0x79cc8917fc90>)
# ERROR:grpc._plugin_wrapping:AuthMetadataPluginCallback "<google.auth.transport.grpc.AuthMetadataPlugin object at 0x79cc890d4e10>" raised exception!
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/compute_engine/credentials.py", line 128, in refresh
#     self._retrieve_info(request)
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/compute_engine/credentials.py", line 101, in _retrieve_info
#     info = _metadata.get_service_account_info(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/compute_engine/_metadata.py", line 323, in get_service_account_info
#     return get(request, path, params={"recursive": "true"})
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/compute_engine/_metadata.py", line 248, in get
#     raise exceptions.TransportError(
# google.auth.exceptions.TransportError: ("Failed to retrieve http://metadata.google.internal/computeMetadata/v1/instance/service-accounts/default/?recursive=true from the Google Compute Engine metadata service. Status: 404 Response:\nb''", <google.auth.transport.requests._Response object at 0x79cc89115150>)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/grpc/_plugin_wrapping.py", line 105, in __call__
#     self._metadata_plugin(
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/transport/grpc.py", line 95, in __call__
#     callback(self._get_authorization_headers(context), None)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/transport/grpc.py", line 81, in _get_authorization_headers
#     self._credentials.before_request(
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/credentials.py", line 228, in before_request
#     self._blocking_refresh(request)
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/credentials.py", line 191, in _blocking_refresh
#     self.refresh(request)
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/compute_engine/credentials.py", line 134, in refresh
#     raise new_exc from caught_exc
# google.auth.exceptions.RefreshError: ("Failed to retrieve http://metadata.google.internal/computeMetadata/v1/instance/service-accounts/default/?recursive=true from the Google Compute Engine metadata service. Status: 404 Response:\nb''", <google.auth.transport.requests._Response object at 0x79cc89115150>)
# ERROR:grpc._plugin_wrapping:AuthMetadataPluginCallback "<google.auth.transport.grpc.AuthMetadataPlugin object at 0x79cc890d4e10>" raised exception!
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/compute_engine/credentials.py", line 128, in refresh
#     self._retrieve_info(request)
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/compute_engine/credentials.py", line 101, in _retrieve_info
#     info = _metadata.get_service_account_info(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/compute_engine/_metadata.py", line 323, in get_service_account_info
#     return get(request, path, params={"recursive": "true"})
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/compute_engine/_metadata.py", line 248, in get
#     raise exceptions.TransportError(
# google.auth.exceptions.TransportError: ("Failed to retrieve http://metadata.google.internal/computeMetadata/v1/instance/service-accounts/default/?recursive=true from the Google Compute Engine metadata service. Status: 404 Response:\nb''", <google.auth.transport.requests._Response object at 0x79cc879fe2d0>)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/grpc/_plugin_wrapping.py", line 105, in __call__
#     self._metadata_plugin(
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/transport/grpc.py", line 95, in __call__
#     callback(self._get_authorization_headers(context), None)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/transport/grpc.py", line 81, in _get_authorization_headers
#     self._credentials.before_request(
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/credentials.py", line 228, in before_request
#     self._blocking_refresh(request)
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/credentials.py", line 191, in _blocking_refresh
#     self.refresh(request)
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/compute_engine/credentials.py", line 134, in refresh
#     raise new_exc from caught_exc
# google.auth.exceptions.RefreshError: ("Failed to retrieve http://metadata.google.internal/computeMetadata/v1/instance/service-accounts/default/?recursive=true from the Google Compute Engine metadata service. Status: 404 Response:\nb''", <google.auth.transport.requests._Response object at 0x79cc879fe2d0>)
# ERROR:grpc._plugin_wrapping:AuthMetadataPluginCallback "<google.auth.transport.grpc.AuthMetadataPlugin object at 0x79cc890d4e10>" raised exception!
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/compute_engine/credentials.py", line 128, in refresh
#     self._retrieve_info(request)
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/compute_engine/credentials.py", line 101, in _retrieve_info
#     info = _metadata.get_service_account_info(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/compute_engine/_metadata.py", line 323, in get_service_account_info
#     return get(request, path, params={"recursive": "true"})
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/compute_engine/_metadata.py", line 248, in get
#     raise exceptions.TransportError(
# google.auth.exceptions.TransportError: ("Failed to retrieve http://metadata.google.internal/computeMetadata/v1/instance/service-accounts/default/?recursive=true from the Google Compute Engine metadata service. Status: 404 Response:\nb''", <google.auth.transport.requests._Response object at 0x79cc9eba2290>)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/grpc/_plugin_wrapping.py", line 105, in __call__
#     self._metadata_plugin(
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/transport/grpc.py", line 95, in __call__
#     callback(self._get_authorization_headers(context), None)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/transport/grpc.py", line 81, in _get_authorization_headers
#     self._credentials.before_request(
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/credentials.py", line 228, in before_request
#     self._blocking_refresh(request)
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/credentials.py", line 191, in _blocking_refresh
#     self.refresh(request)
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/compute_engine/credentials.py", line 134, in refresh
#     raise new_exc from caught_exc
# google.auth.exceptions.RefreshError: ("Failed to retrieve http://metadata.google.internal/computeMetadata/v1/instance/service-accounts/default/?recursive=true from the Google Compute Engine metadata service. Status: 404 Response:\nb''", <google.auth.transport.requests._Response object at 0x79cc9eba2290>)
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/google/api_core/grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      75         try:
# ---> 76             return callable_(*args, **kwargs)
#      77         except grpc.RpcError as exc:
#
# /usr/local/lib/python3.11/dist-packages/grpc/_interceptor.py in __call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     276     ) -> Any:
# --> 277         response, ignored_call = self._with_call(
#     278             request,
#
# /usr/local/lib/python3.11/dist-packages/grpc/_interceptor.py in _with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     331         )
# --> 332         return call.result(), call
#     333
#
# /usr/local/lib/python3.11/dist-packages/grpc/_channel.py in result(self, timeout)
#     439         """See grpc.Future.result."""
# --> 440         raise self
#     441
#
# /usr/local/lib/python3.11/dist-packages/grpc/_interceptor.py in continuation(new_details, request)
#     314             try:
# --> 315                 response, call = self._thunk(new_method).with_call(
#     316                     request,
#
# /usr/local/lib/python3.11/dist-packages/grpc/_channel.py in with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1197         )
# -> 1198         return _end_unary_response_blocking(state, call, True, None)
#    1199
#
# /usr/local/lib/python3.11/dist-packages/grpc/_channel.py in _end_unary_response_blocking(state, call, with_call, deadline)
#    1005     else:
# -> 1006         raise _InactiveRpcError(state)  # pytype: disable=not-instantiable
#    1007
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "Getting metadata from plugin failed with error: ("Failed to retrieve http://metadata.google.internal/computeMetadata/v1/instance/service-accounts/default/?recursive=true from the Google Compute Engine metadata service. Status: 404 Response:\nb''", <google.auth.transport.requests._Response object at 0x79cc9eba2290>)"
# 	debug_error_string = "UNKNOWN:Error received from peer  {created_time:"2025-01-29T05:27:18.712094562+00:00", grpc_status:14, grpc_message:"Getting metadata from plugin failed with error: (\"Failed to retrieve http://metadata.google.internal/computeMetadata/v1/instance/service-accounts/default/?recursive=true from the Google Compute Engine metadata service. Status: 404 Response:\\nb\'\'\", <google.auth.transport.requests._Response object at 0x79cc9eba2290>)"}"
# >
#
# The above exception was the direct cause of the following exception:
#
# ServiceUnavailable                        Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/google/api_core/retry/retry_unary.py in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     143         try:
# --> 144             result = target()
#     145             if inspect.isawaitable(result):
#
# /usr/local/lib/python3.11/dist-packages/google/api_core/timeout.py in func_with_timeout(*args, **kwargs)
#     119
# --> 120             return func(*args, **kwargs)
#     121
#
# /usr/local/lib/python3.11/dist-packages/google/api_core/grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      77         except grpc.RpcError as exc:
# ---> 78             raise exceptions.from_grpc_error(exc) from exc
#      79
#
# ServiceUnavailable: 503 Getting metadata from plugin failed with error: ("Failed to retrieve http://metadata.google.internal/computeMetadata/v1/instance/service-accounts/default/?recursive=true from the Google Compute Engine metadata service. Status: 404 Response:\nb''", <google.auth.transport.requests._Response object at 0x79cc9eba2290>)
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-42918b78d7d1> in <cell line: 0>()
# ----> 1 result = graph.invoke(
#       2     initial_state,
#       3     config1
#       4 )
#
# /usr/local/lib/python3.11/dist-packages/langgraph/pregel/__init__.py in invoke(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, **kwargs)
#    1959         else:
#    1960             chunks = []
# -> 1961         for chunk in self.stream(
#    1962             input,
#    1963             config,
#
# /usr/local/lib/python3.11/dist-packages/langgraph/pregel/__init__.py in stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, subgraphs)
#    1668                 # with channel updates applied only at the transition between steps.
#    1669                 while loop.tick(input_keys=self.input_channels):
# -> 1670                     for _ in runner.tick(
#    1671                         loop.tasks.values(),
#    1672                         timeout=self.step_timeout,
#
# /usr/local/lib/python3.11/dist-packages/langgraph/pregel/runner.py in tick(self, tasks, reraise, timeout, retry_policy, get_waiter)
#     228             t = tasks[0]
#     229             try:
# --> 230                 run_with_retry(
#     231                     t,
#     232                     retry_policy,
#
# /usr/local/lib/python3.11/dist-packages/langgraph/pregel/retry.py in run_with_retry(task, retry_policy, configurable)
#      38             task.writes.clear()
#      39             # run the task
# ---> 40             return task.proc.invoke(task.input, config)
#      41         except ParentCommand as exc:
#      42             ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# /usr/local/lib/python3.11/dist-packages/langgraph/utils/runnable.py in invoke(self, input, config, **kwargs)
#     460                 )
#     461                 if i == 0:
# --> 462                     input = step.invoke(input, config, **kwargs)
#     463                 else:
#     464                     input = step.invoke(input, config)
#
# /usr/local/lib/python3.11/dist-packages/langgraph/utils/runnable.py in invoke(self, input, config, **kwargs)
#     224         else:
#     225             context.run(_set_config_context, config)
# --> 226             ret = context.run(self.func, *args, **kwargs)
#     227         if isinstance(ret, Runnable) and self.recurse:
#     228             return ret.invoke(input, config)
#
# <ipython-input-25-87918047ec3b> in assistant(state)
#       9     system_prompt = SystemMessage(content=get_system_prompt(state))
#      10     messages = [system_prompt] + state['messages']
# ---> 11     response = llm_with_tools.invoke(messages)
#      12     # response = llm.invoke(messages)
#      13     return {"messages": [response]}
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/runnables/base.py in invoke(self, input, config, **kwargs)
#    5350         **kwargs: Optional[Any],
#    5351     ) -> Output:
# -> 5352         return self.bound.invoke(
#    5353             input,
#    5354             self._merge_configs(config),
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/chat_models.py in invoke(self, input, config, stop, **kwargs)
#     282         return cast(
#     283             ChatGeneration,
# --> 284             self.generate_prompt(
#     285                 [self._convert_input(input)],
#     286                 stop=stop,
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/chat_models.py in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     789     ) -> LLMResult:
#     790         prompt_messages = [p.to_messages() for p in prompts]
# --> 791         return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#     792
#     793     async def agenerate_prompt(
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/chat_models.py in generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     636             try:
#     637                 results.append(
# --> 638                     self._generate_with_cache(
#     639                         m,
#     640                         stop=stop,
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/chat_models.py in _generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     854         else:
#     855             if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 856                 result = self._generate(
#     857                     messages, stop=stop, run_manager=run_manager, **kwargs
#     858                 )
#
# /usr/local/lib/python3.11/dist-packages/langchain_google_genai/chat_models.py in _generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#     949             tool_choice=tool_choice,
#     950         )
# --> 951         response: GenerateContentResponse = _chat_with_retry(
#     952             request=request,
#     953             **kwargs,
#
# /usr/local/lib/python3.11/dist-packages/langchain_google_genai/chat_models.py in _chat_with_retry(generation_method, **kwargs)
#     194             raise e
#     195
# --> 196     return _chat_with_retry(**kwargs)
#     197
#     198
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in wrapped_f(*args, **kw)
#     334             copy = self.copy()
#     335             wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 336             return copy(f, *args, **kw)
#     337
#     338         def retry_with(*args: t.Any, **kwargs: t.Any) -> WrappedFn:
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     473         retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     474         while True:
# --> 475             do = self.iter(retry_state=retry_state)
#     476             if isinstance(do, DoAttempt):
#     477                 try:
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in iter(self, retry_state)
#     374         result = None
#     375         for action in self.iter_state.actions:
# --> 376             result = action(retry_state)
#     377         return result
#     378
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in <lambda>(rs)
#     396     def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     397         if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 398             self._add_action_func(lambda rs: rs.outcome.result())
#     399             return
#     400
#
# /usr/lib/python3.11/concurrent/futures/_base.py in result(self, timeout)
#     447                     raise CancelledError()
#     448                 elif self._state == FINISHED:
# --> 449                     return self.__get_result()
#     450
#     451                 self._condition.wait(timeout)
#
# /usr/lib/python3.11/concurrent/futures/_base.py in __get_result(self)
#     399         if self._exception:
#     400             try:
# --> 401                 raise self._exception
#     402             finally:
#     403                 # Break a reference cycle with the exception in self._exception
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     476             if isinstance(do, DoAttempt):
#     477                 try:
# --> 478                     result = fn(*args, **kwargs)
#     479                 except BaseException:  # noqa: B902
#     480                     retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# /usr/local/lib/python3.11/dist-packages/langchain_google_genai/chat_models.py in _chat_with_retry(**kwargs)
#     176     def _chat_with_retry(**kwargs: Any) -> Any:
#     177         try:
# --> 178             return generation_method(**kwargs)
#     179         # Do not retry for these errors.
#     180         except google.api_core.exceptions.FailedPrecondition as exc:
#
# /usr/local/lib/python3.11/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py in generate_content(self, request, model, contents, retry, timeout, metadata)
#     833
#     834         # Send the request.
# --> 835         response = rpc(
#     836             request,
#     837             retry=retry,
#
# /usr/local/lib/python3.11/dist-packages/google/api_core/gapic_v1/method.py in __call__(self, timeout, retry, compression, *args, **kwargs)
#     129             kwargs["compression"] = compression
#     130
# --> 131         return wrapped_func(*args, **kwargs)
#     132
#     133
#
# /usr/local/lib/python3.11/dist-packages/google/api_core/retry/retry_unary.py in retry_wrapped_func(*args, **kwargs)
#     291                 self._initial, self._maximum, multiplier=self._multiplier
#     292             )
# --> 293             return retry_target(
#     294                 target,
#     295                 self._predicate,
#
# /usr/local/lib/python3.11/dist-packages/google/api_core/retry/retry_unary.py in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     162             )
#     163             # if exception not raised, sleep before next attempt
# --> 164             time.sleep(sleep)
#     165
#     166     raise ValueError("Sleep generator stopped yielding sleep values.")
#
# KeyboardInterrupt:
